...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
kmt1 =[]
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)

# %%
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2010', '2016', '2021', '2017', '2017', '2012', '2018', '2018', '2015', '2018', '2017', '2018', '2015', '2015', '2017', '2022', '2012', '2017', '2019', '2013']
# [[' Hyundai', ' i10'], [' Hyundai', ' Grand', ' i10'], [' Maruti', ' Ciaz'], [' Honda', ' WR'], [' Maruti', ' Baleno'], [' Hyundai', ' i20'], [' Hyundai', ' Elite', ' i20'], [' Honda', ' Amaze'], [' Maruti', ' Alto', ' 800'], [' Hyundai', ' NEW', ' SANTRO'], [' Maruti', ' Celerio', ' X'], [' Maruti', ' Alto', ' 800'], [' Renault', ' Duster'], [' Honda', ' Jazz'], [' Maruti', ' Swift'], [' Tata', ' ALTROZ'], [' Volkswagen', ' Polo'], [' Maruti', ' Ciaz'], [' Maruti', ' XL6'], [' Hyundai', ' i10']]
# ['Attapur, Hyderabad', 'Attapur, Hyderabad', 'Kompally, Hyderabad', 'Bachupally, Hyderabad', 'Vanasthalipuram, Hyderabad.\n', 'Kompally, Hyderabad', 'Kompally, Hyderabad', 'Bachupally, Hyderabad', 'Bachupally, Hyderabad', 'Attapur, Hyderabad', 'Bachupally, Hyderabad', 'Vanasthalipuram, Hyderabad.\n', 'Bachupally, Hyderabad', 'Bachupally, Hyderabad', 'Kompally, Hyderabad', 'Kompally, Hyderabad', nan, 'Kompally, Hyderabad', 'Kompally, Hyderabad', 'Kompally, Hyderabad']
# [['57,942'], ['75,568'], ['41,362'], ['53,535'], ['41,260'], ['92,054'], ['89,269'], ['97,090'], ['72,308'], ['92,388'], ['48,408'], ['48,542'], ['98,087'], ['51,895'], ['77,321'], ['9,638'], ['67,852'], ['79,751'], ['55,188'], ['16,213']]
# [['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Automatic'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Automatic'], ['Automatic']]
# ['247000', '453000', '819000', '661000', '591000', '377000', '763000', '608000', '264000', '433000', '487000', '328000', '500000', '506000', '589000', '961000', '364000', '753000', '1043000', '404000']

# %%
dicto = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto["Kmt run"]
for i in dicto["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

# %%
dicton = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicton
# Out:
# {'Name of Cars': [[' Hyundai', ' i10'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Maruti', ' Ciaz'],
#   [' Honda', ' WR'],
#   [' Maruti', ' Baleno'],
#   [' Hyundai', ' i20'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Honda', ' Amaze'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Hyundai', ' NEW', ' SANTRO'],
#   [' Maruti', ' Celerio', ' X'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Renault', ' Duster'],
#   [' Honda', ' Jazz'],
#   [' Maruti', ' Swift'],
#   [' Tata', ' ALTROZ'],
#   [' Volkswagen', ' Polo'],
#   [' Maruti', ' Ciaz'],
#   [' Maruti', ' XL6'],
#   [' Hyundai', ' i10']],
#  'Registration Year': ['2010',
#   '2016',
#   '2021',
#   '2017',
#   '2017',
#   '2012',
#   '2018',
#   '2018',
#   '2015',
#   '2018',
#   '2017',
#   '2018',
#   '2015',
#   '2015',
#   '2017',
#   '2022',
#   '2012',
#   '2017',
#   '2019',
#   '2013'],
#  'Kmt run': [57942,
#   75568,
#   41362,
#   53535,
#   41260,
#   92054,
#   89269,
#   97090,
#   72308,
#   92388,
#   48408,
#   48542,
#   98087,
#   51895,
#   77321,
#   9638,
#   67852,
#   79751,
#   55188,
#   16213],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Automatic']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['247000',
#   '453000',
#   '819000',
#   '661000',
#   '591000',
#   '377000',
#   '763000',
#   '608000',
#   '264000',
#   '433000',
#   '487000',
#   '328000',
#   '500000',
#   '506000',
#   '589000',
#   '961000',
#   '364000',
#   '753000',
#   '1043000',
#   '404000'],
#  'Location of car': ['Attapur, Hyderabad',
#   'Attapur, Hyderabad',
#   'Kompally, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Vanasthalipuram, Hyderabad.\n',
#   'Kompally, Hyderabad',
#   'Kompally, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Attapur, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Vanasthalipuram, Hyderabad.\n',
#   'Bachupally, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Kompally, Hyderabad',
#   'Kompally, Hyderabad',
#   nan,
#   'Kompally, Hyderabad',
#   'Kompally, Hyderabad',
#   'Kompally, Hyderabad']}

# %% [markdown]
# # 2nd

# %%
url2 = "https://www.cars24.com/buy-used-car?sort=lhl&serveWarrantyCount=true&listingSource=Homepage_Filters&storeCityId=3686&pinId=500002"

# %%
new1 = req.get(url2)
new1
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new1.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n878 Used Cars in Hyderabad - Second Hand Cars for Sale\n\n HyderabadBuy a carPopular makesMarutiHyundaiHondaRenaultTataVolkswagenDatsunFordMahindraNissanView all makesPopular ModelsHyundai i10Hyundai i20Maruti SwiftMaruti Wagon RHonda CityMaruti AltoMaruti DzireMaruti BalenoRenault KwidTata TiagoView all modelsBody typeHatchbackSedanSUVLuxury SUVLuxury SedanFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Swift (51)Honda City (47)Hyundai Elite i20 (43)Hyundai Grand i10 (40)Maruti Baleno (38)Renault Kwid (36)ALL BRANDSMaruti (315)Hyundai (210)Honda (94)Renault (59)Tata (57)Volkswagen (30)Datsun (23)Ford (20)Mahindra (14)Nissan (14)Toyota (12)Skoda (9)KIA (8)Jeep (7)MG (6)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Volvo (0)Jaguar (0)Budget₹ 1,50,000₹ 25,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All878 Used cars in HyderabadSort By:Recently Added  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New2010 Hyundai i10MAGNA 1.2Manual57,942 km2nd OwnerPetrolAP-28₹3,863/month ₹49,400 downpayment₹2,47,000Attapur, Hyderabad2016 Hyundai Grand i101.2 SPORTZ PRIME EDITION VTVTManual75,568 km1st OwnerPetrolTS-07₹7,085/month ₹90,600 downpayment₹4,53,000Attapur, HyderabadNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility 2021 Maruti CiazSIGMA 1.5 SHVS MT  PETROLManual41,362 km1st OwnerPetrolTS-07₹12,471/month ₹1,63,800 downpayment₹8,19,000Kompally, Hyderabad2017 Honda WR-V1.5L I-DTEC S MTManual53,535 km1st OwnerDieselTS-07₹10,338/month ₹1,32,200 downpayment₹6,61,000Bachupally, Hyderabad2017 Maruti BalenoDELTA CVT PETROL 1.2Automatic41,260 km2nd OwnerPetrolTS-07₹9,243/month ₹1,18,200 downpayment₹5,91,000Vanasthalipuram, H
= {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto2["Kmt run"]
for i in dicto2["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

# %%
dicto2n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto2n
# Out:
# {'Name of Cars': [[' Hyundai', ' i10'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Maruti', ' Ciaz'],
#   [' Honda', ' WR'],
#   [' Maruti', ' Baleno'],
#   [' Hyundai', ' i20'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Honda', ' Amaze'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Hyundai', ' NEW', ' SANTRO'],
#   [' Maruti', ' Celerio', ' X'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Renault', ' Duster'],
#   [' Honda', ' Jazz'],
#   [' Maruti', ' Swift'],
#   [' Tata', ' ALTROZ'],
#   [' Volkswagen', ' Polo'],
#   [' Maruti', ' Ciaz'],
#   [' Maruti', ' XL6'],
#   [' Hyundai', ' i10']],
#  'Registration Year': ['2010',
#   '2016',
#   '2021',
#   '2017',
#   '2017',
#   '2012',
#   '2018',
#   '2018',
#   '2015',
#   '2018',
#   '2017',
#   '2018',
#   '2015',
#   '2015',
#   '2017',
#   '2022',
#   '2012',
#   '2017',
#   '2019',
#   '2013'],
#  'Kmt run': [57942,
#   75568,
#   41362,
#   53535,
#   41260,
#   92054,
#   89269,
#   97090,
#   72308,
#   92388,
#   48408,
#   48542,
#   98087,
#   51895,
#   77321,
#   9638,
#   67852,
#   79751,
#   55188,
#   16213],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Automatic']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['247000',
#   '453000',
#   '819000',
#   '661000',
#   '591000',
#   '377000',
#   '763000',
#   '608000',
#   '264000',
#   '433000',
#   '487000',
#   '328000',
#   '500000',
#   '506000',
#   '589000',
#   '961000',
#   '364000',
#   '753000',
#   '1043000',
#   '404000'],
#  'Location of car': ['Attapur, Hyderabad',
#   'Attapur, Hyderabad',
#   'Kompally, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Vanasthalipuram, Hyderabad.\n',
#   'Kompally, Hyderabad',
#   'Kompally, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Attapur, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Vanasthalipuram, Hyderabad.\n',
#   'Bachupally, Hyderabad',
#   'Bachupally, Hyderabad',
#   'Kompally, Hyderabad',
#   'Kompally, Hyderabad',
#   nan,
#   'Kompally, Hyderabad',
#   'Kompally, Hyderabad',
#   'Kompally, Hyderabad']}

# %% [markdown]
# # 3

# %%
url3 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Amaruti&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&listingSource=TabFilter&storeCityId=2&pinId=110001"

# %%
new3 = req.get(url3)
new3
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new3.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n817 Used Cars in New Delhi - Second Hand Cars for Sale\n\n New DelhiBuy a carPopular makesMarutiHyundaiHondaRenaultTataFordToyotaVolkswagenMahindraKIAView all makesPopular ModelsMaruti BalenoHyundai i10Honda CityMaruti Wagon RMaruti SwiftMaruti AltoHonda AmazeHyundai i20Maruti CelerioHyundai CretaView all modelsBody typeHatchbackSedanSUVLuxury SUVLuxury SedanFuel typePetrolCNGDieselTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Baleno (161)Maruti Swift (125)Honda City (108)Honda Amaze (89)Maruti Wagon R 1.0 (76)Hyundai Grand i10 (65)ALL BRANDSMaruti (817)Hyundai (423)Honda (266)Tata (99)Renault (72)Toyota (62)Mahindra (43)Ford (41)Volkswagen (32)Datsun (28)KIA (25)Nissan (19)Jeep (16)Skoda (10)MG (5)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Volvo (0)Jaguar (0)Budget₹ 1,00,000₹ 30,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All817 Used cars in New DelhiSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹19,000off2019 Maruti Vitara BrezzaVDIManual55,523 km1st OwnerDieselHR-30₹12,182/month ₹1,60,000 downpayment₹8,00,000₹8,19,000M3M Urbana, Golf Course Ext., Gurugram₹41,000off2015 Maruti SwiftVDI ABSManual1,17,499 km1st OwnerDieselHR-30₹5,881/month ₹75,200 downpayment₹3,76,000₹4,17,000Spaze Platinum, Sohna Road, GurugramNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹23,000off2018 Maruti SwiftVXIManual91,534 km2nd OwnerPetrolHR-50₹8,039/month ₹1,02,800 downpayment₹5,14,000₹5,37,000M3M Urbana, Golf Course Ext., Gurugram₹37,000off2019 Maruti Vitara BrezzaVDIManual50,767 km1st OwnerDieselHR-29₹12,231/month ₹1,56,400 downpayment₹7,82,000₹8,19,000M3M Urbana, Golf Course Ext., Gurugram2015 Maruti Alto 800LXIManual35,843 km3rd OwnerPetrolHR-29₹3,660/month ₹46,800 downpayment₹2,34,000Spaze Platinum, Sohna Road, GurugramUsed cars in New Delhi by brandMarutiHyundaiHondaRenaultTataFordToyotaVolkswagenMahindraDatsunKIANissanJeepSkodaMGBMWAudiMercedes Benz₹72,000off2019 Maruti BalenoDELTA PETROL 1.2Manual97,494 km1st OwnerPetrolHR-30₹7,210/month ₹92,200 downpayment₹4,61,000₹5,33,000Spaze Platinum, Sohna Road, Gurugram₹34,000off2019 Maruti New Wagon-RLXI CNG 1.0Manual48,404 km1st OwnerCNGHR-29₹7,210/month ₹92,200 downpayment₹4,61,000₹4,95,000Metro Walk, Rohini, New Delhi2014 Maruti Wagon R 1.0VXIManual97,752 km1st OwnerPetrolHR-30₹4,583/month ₹58,600 downpayment₹2,93,000Spaze Platinum, Sohna Road, GurugramUsed cars in New Delhi by body typeHatchbackSedanSUVLuxury SUVLuxury Sedan₹31,000off2014 Maruti Wagon R 1.0VXIManual79,204 km2nd OwnerPetrolHR-30₹3,894/month ₹49,800 downpayment₹2,49,000₹2,80,000Spaze Platinum, Sohna Road, Gurugram₹45,000off2018 Maruti Vita ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)

# %%
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2019', '2015', '2018', '2019', '2015', '2019', '2019', '2014', '2014', '2018', '2010', '2019', '2020', '2014', '2018', '2016', '2014', '2016', '2019', '2017']
# [[' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Swift'], [' Maruti', ' Swift'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Baleno'], [' Maruti', ' New', ' Wagon'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' Alto'], [' Maruti', ' Swift'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Swift'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Celerio', ' X'], [' Maruti', ' Alto', ' 800']]
# ['M3M Urbana, Golf Course Ext., Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'M3M Urbana, Golf Course Ext., Gurugram', 'M3M Urbana, Golf Course Ext., Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Metro Walk, Rohini, New Delhi', 'Spaze Platinum, Sohna Road, Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Parsvnath City Mall, Faridabad', 'Chhatarpur, Delhi\n', 'GIP Mall, Noida', 'Metro Walk, Rohini, New Delhi', 'Spaze Platinum, Sohna Road, Gurugram', 'Metro Walk, Rohini, New Delhi', 'Parsvnath City Mall, Faridabad', 'Spaze Platinum, Sohna Road, Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Metro Walk, Rohini, New Delhi', 'Metro Walk, Rohini, New Delhi']
# [['55,523'], ['1,17', ',499'], ['91,534'], ['50,767'], ['35,843'], ['97,494'], ['48,404'], ['97,752'], ['79,204'], ['30,549'], ['61,569'], ['18,475'], ['44,817'], ['47,899'], ['34,966'], ['89,634'], ['1,02', ',337'], ['32,031'], ['54,711'], ['25,868']]
# [['Diesel'], ['Diesel'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['800000', '376000', '514000', '782000', '234000', '461000', '461000', '293000', '249000', '703000', '181000', '340000', '526000', '243000', '563000', '244000', '224000', '293000', '473000', '321000']

# %%
dicto3 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto3["Kmt run"]
for i in dicto3["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

# %%
dicto3n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto3n
# Out:
# {'Name of Cars': [[' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Baleno'],
#   [' Maruti', ' New', ' Wagon'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Alto'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Celerio', ' X'],
#   [' Maruti', ' Alto', ' 800']],
#  'Registration Year': ['2019',
#   '2015',
#   '2018',
#   '2019',
#   '2015',
#   '2019',
#   '2019',
#   '2014',
#   '2014',
#   '2018',
#   '2010',
#   '2019',
#   '2020',
#   '2014',
#   '2018',
#   '2016',
#   '2014',
#   '2016',
#   '2019',
#   '2017'],
#  'Kmt run': [55523,
#   117499,
#   91534,
#   50767,
#   35843,
#   97494,
#   48404,
#   97752,
#   79204,
#   30549,
#   61569,
#   18475,
#   44817,
#   47899,
#   34966,
#   89634,
#   102337,
#   32031,
#   54711,
#   25868],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['800000',
#   '376000',
#   '514000',
#   '782000',
#   '234000',
#   '461000',
#   '461000',
#   '293000',
#   '249000',
#   '703000',
#   '181000',
#   '340000',
#   '526000',
#   '243000',
#   '563000',
#   '244000',
#   '224000',
#   '293000',
#   '473000',
#   '321000'],
#  'Location of car': ['M3M Urbana, Golf Course Ext., Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'M3M Urbana, Golf Course Ext., Gurugram',
#   'M3M Urbana, Golf Course Ext., Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Metro Walk, Rohini, New Delhi',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Parsvnath City Mall, Faridabad',
#   'Chhatarpur, Delhi\n',
#   'GIP Mall, Noida',
#   'Metro Walk, Rohini, New Delhi',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Metro Walk, Rohini, New Delhi',
#   'Parsvnath City Mall, Faridabad',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   '
],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Hyundai', ' Xcent'],
#   [' Hyundai', ' Eon']],
#  'Registration Year': ['2012',
#   '2014',
#   '2019',
#   '2018',
#   '2010',
#   '2022',
#   '2013',
#   '2021',
#   '2016',
#   '2011',
#   '2015',
#   '2017',
#   '2012',
#   '2019',
#   '2020',
#   '2016',
#   '2020',
#   '2019',
#   '2017',
#   '2017'],
#  'Kmt run': [88748,
#   64814,
#   43804,
#   67470,
#   87197,
#   4344,
#   105286,
#   51463,
#   115488,
#   124420,
#   76494,
#   116263,
#   105830,
#   82074,
#   69761,
#   107787,
#   30099,
#   108140,
#   36486,
#   91991],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   nan,
#   ['Petrol'],
#   nan,
#   ['Diesel'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan],
#  'Price': ['233000',
#   '355000',
#   '863000',
#   '621000',
#   '167000',
#   '1254000',
#   '287000',
#   '1451000',
#   '503000',
#   '199000',
#   '334000',
#   '552000',
#   '173000',
#   '988000',
#   '949000',
#   '772000',
#   '1389000',
#   '581000',
#   '481000',
#   '280000'],
#  'Location of car': ['Karnavati Club, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Karnavati Club, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Karnavati Club, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Karnavati Club, Ahmedabad',
#   'Karnavati Club, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Karnavati Club, Ahmedabad',
#   'Karnavati Club, Ahmedabad',
#   'Naroda, Ahmedabad',
#   'Karnavati Club, Ahmedabad',
#   'Karnavati Club, Ahmedabad']}

# %%
url5 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=4709&pinId=560001"

# %%
new5 = req.get(url5)
new5
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new5.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n402 Used Cars in Bangalore - Second Hand Cars for Sale\n\n BangaloreBuy a carPopular makesMarutiHyundaiHondaRenaultTataMahindraFordVolkswagenKIAToyotaView all makesPopular ModelsHyundai i10Hyundai i20Maruti SwiftMaruti CelerioMaruti BalenoMaruti AltoRenault KwidMaruti DzireHonda CityMaruti Wagon RView all modelsBody typeHatchbackSUVSedanLuxury SUVLuxury SedanFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Swift (118)Hyundai Grand i10 (94)Maruti Celerio (72)Maruti Baleno (70)Hyundai Elite i20 (70)Renault Kwid (60)ALL BRANDSMaruti (558)Hyundai (402)Honda (141)Renault (111)Tata (72)Mahindra (50)Ford (46)Volkswagen (35)KIA (27)Toyota (18)Skoda (16)Nissan (12)Datsun (8)Jeep (4)MG (4)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Volvo (0)Jaguar (0)Budget₹ 2,00,000₹ 25,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All402 Used cars in BangaloreSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹23,000off2011 Hyundai VernaFLUIDIC 1.6 CRDI EXManual83,963 km2nd OwnerDieselKA-03₹5,834/month ₹74,600 downpayment₹3,73,000₹3,96,000Whitefield Main Road, Bhoruka Tech Park, Benga...2012 Hyundai i10SPORTZ 1.2Manual74,961 km3rd OwnerPetrolKA-18₹4,520/month ₹57,800 downpayment₹2,89,000Whitefield Main Road, Bhoruka Tech Park, Benga...Need a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility 2015 Hyundai i20 Active1.2 SManual56,366 km2nd OwnerPetrolKA-03₹8,102/month ₹1,03,600 downpayment₹5,18,000Bellahalli, Bengaluru2012 Hyundai i10SPORTZ 1.2Manual50,312 km1st OwnerPetrolKA-05₹5,396/month ₹69,000 downpayment₹3,45,000Whitefield Main Road, Bhoruka Tech Park, Benga...2016 Hyundai CretaE PLUS 1.6 PETROLManual46,063 km2nd OwnerPetrolKA-53₹12,913/month ₹1,69,600 downpayment₹8,48,000Bellahalli, BengaluruUsed cars in Bangalore by brandMarutiHyundaiHondaRenaultTataMahindraFordVolkswagenKIAToyotaSkodaNissanDatsunJeepMGFiatMercedes Benz₹65,000off2016 Hyundai CretaSX PLUS 1.6 PETROLManual81,853 km2nd OwnerPetrolKA-01₹13,156/month ₹1,72,800 downpayment₹8,64,000₹9,29,000Bellahalli, Bengaluru2016 Hyundai VernaFLUIDIC 4S 1.6 VTVT S ATAutomatic62,295 km2nd OwnerPetrolKA-51₹8,712/month ₹1,11,400 downpayment₹5,57,000Bellahalli, Bengaluru2010 Hyundai i10MAGNA 1.2Manual1,16,372 km2nd OwnerPetrolKA-53₹3,847/month ₹49,200 downpayment₹2,46,000Bellahalli, BengaluruUsed cars in Bangalore by body typeHatchbackSUVSedanLuxury SUVLuxury Sedan₹11,000off2015 Hyundai VernaFLUIDIC 4S 1.6 VTVT S(O)Manual95,193 km2nd OwnerPetrolKA-04₹8,852/month ₹1,13,200 downpayment₹5,66,000₹5,77,000Bellahalli, Bengaluru2019 Hyundai VENUESX PLUS 1.0 TURBO DCTAutomatic27,530 km1st OwnerPetrolKA-03₹15,319/month ₹2,01,200 downpa ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)

# %%
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2011', '2012', '2015', '2012', '2016', '2016', '2016', '2010', '2015', '2019', '2014', '2014', '2014', '2019', '2014', '2017', '2014', '2012', '2016', '2010']
# [[' Hyundai', ' Verna'], [' Hyundai', ' i10'], [' Hyundai', ' i20', ' Active'], [' Hyundai', ' i10'], [' Hyundai', ' Creta'], [' Hyundai', ' Creta'], [' Hyundai', ' Verna'], [' Hyundai', ' i10'], [' Hyundai', ' Verna'], [' Hyundai', ' VENUE'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' Eon'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' NEW', ' SANTRO'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' i20'], [' Hyundai', ' Creta'], [' Hyundai', ' i10']]
# ['Whitefield Main Road, Bhoruka Tech Park, Benga...', 'Whitefield Main Road, Bhoruka Tech Park, Benga...', 'Bellahalli, Bengaluru', 'Whitefield Main Road, Bhoruka Tech Park, Benga...', 'Bellahalli, Bengaluru', 'Bellahalli, Bengaluru', 'Bellahalli, Bengaluru', 'Bellahalli, Bengaluru', 'Bellahalli, Bengaluru', 'Garuda Mall, Magrath Road, Bengaluru', 'Bellahalli, Bengaluru', 'Sonnappanahalli\n', 'Bellahalli, Bengaluru', 'GT World Mall, Bengaluru', 'Bellahalli, Bengaluru', 'Bellahalli, Bengaluru', 'Bellahalli, Bengaluru', 'Bellahalli, Bengaluru', 'Whitefield Main Road, Bhoruka Tech Park, Benga...', 'Whitefield Main Road, Bhoruka Tech Park, Benga...']
# [['83,963'], ['74,961'], ['56,366'], ['50,312'], ['46,063'], ['81,853'], ['62,295'], ['1,16', ',372'], ['95,193'], ['27,530'], ['42,627'], ['29,940'], ['38,830'], ['21,302'], ['26,002'], ['28,418'], ['46,110'], ['64,958'], ['37,550'], ['43,529']]
# [['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Automatic'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['373000', '289000', '518000', '345000', '848000', '864000', '557000', '246000', '566000', '1006000', '498000', '296000', '438000', '473000', '450000', '553000', '451000', '347000', '838800', '258000']

# %%
dicto5 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto5["Kmt run"]
for i in dicto5["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto5n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto5n
# Out:
# {'Name of Cars': [[' Hyundai', ' Verna'],
#   [' Hyundai', ' i10'],
#   [' Hyundai', ' i20', ' Active'],
#   [' Hyundai', ' i10'],
#   [' Hyundai', ' Creta'],
#   [' Hyundai', ' Creta'],
#   [' Hyundai', ' Verna'],
#   [' Hyundai', ' i10'],
#   [' Hyundai', ' Verna'],
#   [' Hyundai', ' VENUE'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' Eon'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' NEW', ' SANTRO'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' i20'],
#   [' Hyundai', ' Creta'],
#   [' Hyundai', ' i10']],
#  'Registration Year': ['2011',
#   '2012',
#   '2015',
#   '2012',
#   '2016',
#   '2016',
#   '2016',
#   '2010',
#   '2015',
#   '2019',
#   '2014',
#   '2014',
#   '2014',
#   '2019',
#   '2014',
#   '2017',
#   '2014',
#   '2012',
#   '2016',
#   '2010'],
#  'Kmt run': [83963,
#   74961,
#   56366,
#   50312,
#   46063,
#   81853,
#   62295,
#   116372,
#   95193,
#   27530,
#   42627,
#   29940,
#   38830,
#   21302,
#   26002,
#   28418,
#   46110,
#   64958,
#   37550,
#   43529],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['373000',
#   '289000',
#   '518000',
#   '345000',
#   '848000',
#   '864000',
#   '557000',
#   '246000',
#   '566000',
#   '1006000',
#   '498000',
#   '296000',
#   '438000',
#   '473000',
#   '450000',
#   '553000',
#   '451000',
#   '347000',
#   '838800',
#   '258000'],
#  'Location of car': ['Whitefield Main Road, Bhoruka Tech Park, Benga...',
#   'Whitefield Main Road, Bhoruka Tech Park, Benga...',
#   'Bellahalli, Bengaluru',
#   'Whitefield Main Road, Bhoruka Tech Park, Benga...',
#   'Bellahalli, Bengaluru',
#   'Bellahalli, Bengaluru',
#   'Bellahalli, Bengaluru',
#   'Bellahalli, Bengaluru',
#   'Bellahalli, Bengaluru',
#   'Garuda Mall, Magrath Road, Bengaluru',
#   'Bellahalli, Bengaluru',
#   'Sonnappanahalli\n',
#   'Bellahalli, Bengaluru',
#   'GT World Mall, Bengaluru',
#   'Bellahalli, Bengaluru',
#   'Bellahalli, Bengaluru',
#   'Bellahalli, Bengaluru',
#   'Bellahalli, Bengaluru',
#   'Whitefield Main Road, Bhoruka Tech Park, Benga...',
#   'Whitefield Main Road, Bhoruka Tech Park, Benga...']}

# %%
url6 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&listingSource=TabFilter&storeCityId=5732&pinId=600001"

# %%
new6 = req.get(url6)
new6
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new6.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2011', '2019', '2019', '2021', '2015', '2014', '2019', '2013', '2017', '2018', '2022', '2016', '2016', '2019', '2011', '2019', '2016', '2017', '2018', '2016']
# [[' Hyundai', ' Verna'], [' Hyundai', ' VENUE'], [' Hyundai', ' VENUE'], [' Hyundai', ' NEW', ' SANTRO'], [' Maruti', ' Alto', ' K10'], [' Hyundai', ' Elite', ' i20'], [' Maruti', ' New', ' Wagon'], [' Maruti', ' Swift'], [' Maruti', ' IGNIS'], [' Hyundai', ' Xcent'], [' Maruti', ' Swift'], [' Maruti', ' Celerio'], [' Hyundai', ' i10'], [' Maruti', ' Baleno'], [' Hyundai', ' i10'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' Verna'], [' Hyundai', ' Elite', ' i20']]
# ['Thiruverkadu, Chennai\n', 'Navalur', 'Thiruverkadu, Chennai\n', 'Navalur', 'Navalur', 'Thiruverkadu, Chennai\n', 'Thiruverkadu, Chennai\n', 'Thiruverkadu, Chennai\n', 'Navalur', 'Navalur', 'Navalur', 'Navalur', 'Navalur', 'Navalur', 'Thiruverkadu, Chennai\n', 'Navalur', 'Navalur', 'Thiruverkadu, Chennai\n', 'Navalur', 'Navalur']
# [['1,17', ',255'], ['53,193'], ['63,061'], ['20,586'], ['61,739'], ['1,12', ',184'], ['47,181'], ['88,192'], ['42,365'], ['33,682'], ['51,140'], ['88,890'], ['60,778'], ['82,425'], ['59,947'], ['40,240'], ['57,479'], ['36,882'], ['32,220'], ['35,451']]
# [['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Automatic'], ['Automatic'], ['Automatic'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['343000', '984000', '950000', '601000', '313000', '486000', '547000', '360000', '573000', '628000', '679000', '446000', '416000', '550000', '243000', '509000', '482000', '565000', '794000', '575000']

# %%
dicto6 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto6["Kmt run"]
for i in dicto6["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto6n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto6n
# Out:
# {'Name of Cars': [[' Hyundai', ' Verna'],
#   [' Hyundai', ' VENUE'],
#   [' Hyundai', ' VENUE'],
#   [' Hyundai', ' NEW', ' SANTRO'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Maruti', ' New', ' Wagon'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' IGNIS'],
#   [' Hyundai', ' Xcent'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Celerio'],
#   [' Hyundai', ' i10'],
#   [' Maruti', ' Baleno'],
#   [' Hyundai', ' i10'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' Verna'],
#   [' Hyundai', ' Elite', ' i20']],
#  'Registration Year': ['2011',
#   '2019',
#   '2019',
#   '2021',
#   '2015',
#   '2014',
#   '2019',
#   '2013',
#   '2017',
#   '2018',
#   '2022',
#   '2016',
#   '2016',
#   '2019',
#   '2011',
#   '2019',
#   '2016',
#   '2017',
#   '2018',
#   '2016'],
#  'Kmt run': [117255,
#   53193,
#   63061,
#   20586,
#   61739,
#   112184,
#   47181,
#   88192,
#   42365,
#   33682,
#   51140,
#   88890,
#   60778,
#   82425,
#   59947,
#   40240,
#   57479,
#   36882,
#   32220,
#   35451],
#  'Transmission': [['Manual'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['343000',
#   '984000',
#   '950000',
#   '601000',
#   '313000',
#   '486000',
#   '547000',
#   '360000',
#   '573000',
#   '628000',
#   '679000',
#   '446000',
#   '416000',
#   '550000',
#   '243000',
#   '509000',
#   '482000',
#   '565000',
#   '794000',
#   '575000'],
#  'Location of car': ['Thiruverkadu, Chennai\n',
#   'Navalur',
#   'Thiruverkadu, Chennai\n',
#   'Navalur',
#   'Navalur',
#   'Thiruverkadu, Chennai\n',
#   'Thiruverkadu, Chennai\n',
#   'Thiruverkadu, Chennai\n',
#   'Navalur',
#   'Navalur',
#   'Navalur',
#   'Navalur',
#   'Navalur',
#   'Navalur',
#   'Thiruverkadu, Chennai\n',
#   'Navalur',
#   'Navalur',
#   'Thiruverkadu, Chennai\n',
#   'Navalur',
#   'Navalur']}

# %%
url7 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=5&pinId=122001"

# %%
new7 = req.get(url7)
new7
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new7.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n1240 Used Cars in Gurgaon - Second Hand Cars for Sale\n\n GurgaonBuy a carPopular makesMarutiHyundaiHondaTataRenaultToyotaMahindraFordKIANissanView all makesPopular ModelsMaruti BalenoMaruti Wagon RMaruti SwiftHyundai i20Hyundai i10Maruti AltoMaruti BrezzaHyundai CretaRenault KwidMaruti CelerioView all modelsBody typeHatchbackSUVSedanLuxury SUVLuxury SedanFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Baleno (161)Maruti Swift (125)Honda City (108)Honda Amaze (89)Maruti Wagon R 1.0 (76)Hyundai Grand i10 (65)ALL BRANDSMaruti (817)Hyundai (423)Honda (266)Tata (99)Renault (72)Toyota (62)Mahindra (43)Ford (41)Volkswagen (32)Datsun (28)KIA (25)Nissan (19)Jeep (16)Skoda (10)MG (5)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Volvo (0)Jaguar (0)Budget₹ 1,00,000₹ 30,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All1240 Used cars in GurgaonSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹34,000off2020 Hyundai AURAS 1.2 CNGManual67,853 km2nd OwnerCNGUP-13₹10,448/month ₹1,33,600 downpayment₹6,68,000₹7,02,000Sector-18, Noida₹19,000off2019 Maruti Vitara BrezzaVDIManual55,523 km1st OwnerDieselHR-30₹12,182/month ₹1,60,000 downpayment₹8,00,000₹8,19,000M3M Urbana, Golf Course Ext., GurugramNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹41,000off2015 Maruti SwiftVDI ABSManual1,17,499 km1st OwnerDieselHR-30₹5,881/month ₹75,200 downpayment₹3,76,000₹4,17,000Spaze Platinum, Sohna Road, Gurugram₹23,000off2018 Maruti SwiftVXIManual91,534 km2nd OwnerPetrolHR-50₹8,039/month ₹1,02,800 downpayment₹5,14,000₹5,37,000M3M Urbana, Golf Course Ext., Gurugram₹37,000off2019 Maruti Vitara BrezzaVDIManual50,767 km1st OwnerDieselHR-29₹12,231/month ₹1,56,400 downpayment₹7,82,000₹8,19,000M3M Urbana, Golf Course Ext., GurugramUsed cars in Gurgaon by brandMarutiHyundaiHondaTataToyotaRenaultMahindraFordKIANissanJeepDatsunMGVolkswagenSkodaFiatBMWAudi2015 Maruti Alto 800LXIManual35,843 km3rd OwnerPetrolHR-29₹3,660/month ₹46,800 downpayment₹2,34,000Spaze Platinum, Sohna Road, Gurugram₹72,000off2019 Maruti BalenoDELTA PETROL 1.2Manual97,494 km1st OwnerPetrolHR-30₹7,210/month ₹92,200 downpayment₹4,61,000₹5,33,000Spaze Platinum, Sohna Road, Gurugram₹34,000off2019 Maruti New Wagon-RLXI CNG 1.0Manual48,404 km1st OwnerCNGHR-29₹7,210/month ₹92,200 downpayment₹4,61,000₹4,95,000Metro Walk, Rohini, New DelhiUsed cars in Gurgaon by body typeHatchbackSUVSedanLuxury SUVLuxury Sedan2014 Maruti Wagon R 1.0VXIManual97,752 km1st OwnerPetrolHR-30₹4,583/month ₹58,600 downpayment₹2,93,000Spaze Platinum, Sohna Road, Gurugram₹31,000off2014 Maruti Wagon R 1.0VXIManual79,204 km2nd OwnerPet ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)

# %%
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2020', '2019', '2015', '2018', '2019', '2015', '2019', '2019', '2014', '2014', '2018', '2010', '2019', '2020', '2014', '2018', '2016', '2014', '2016', '2017']
# [[' Hyundai', ' AURA'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Swift'], [' Maruti', ' Swift'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Baleno'], [' Maruti', ' New', ' Wagon'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' Alto'], [' Maruti', ' Swift'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Swift'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Alto', ' K10'], [' Hyundai', ' Elite', ' i20']]
# ['Sector-18, Noida', 'M3M Urbana, Golf Course Ext., Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'M3M Urbana, Golf Course Ext., Gurugram', 'M3M Urbana, Golf Course Ext., Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Metro Walk, Rohini, New Delhi', 'Spaze Platinum, Sohna Road, Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Parsvnath City Mall, Faridabad', 'Chhatarpur, Delhi\n', 'GIP Mall, Noida', 'Metro Walk, Rohini, New Delhi', 'Spaze Platinum, Sohna Road, Gurugram', 'Metro Walk, Rohini, New Delhi', 'Parsvnath City Mall, Faridabad', 'Spaze Platinum, Sohna Road, Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Parsvnath City Mall, Faridabad']
# [['67,853'], ['55,523'], ['1,17', ',499'], ['91,534'], ['50,767'], ['35,843'], ['97,494'], ['48,404'], ['97,752'], ['79,204'], ['30,549'], ['61,569'], ['18,475'], ['44,817'], ['47,899'], ['34,966'], ['89,634'], ['1,02', ',337'], ['32,031'], ['81,711']]
# [nan, ['Diesel'], ['Diesel'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['668000', '800000', '376000', '514000', '782000', '234000', '461000', '461000', '293000', '249000', '703000', '181000', '340000', '526000', '243000', '563000', '244000', '224000', '293000', '570000']

# %%
dicto7 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto7["Kmt run"]
for i in dicto7["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto7n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto7n
# Out:
# {'Name of Cars': [[' Hyundai', ' AURA'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Baleno'],
#   [' Maruti', ' New', ' Wagon'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Alto'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Hyundai', ' Elite', ' i20']],
#  'Registration Year': ['2020',
#   '2019',
#   '2015',
#   '2018',
#   '2019',
#   '2015',
#   '2019',
#   '2019',
#   '2014',
#   '2014',
#   '2018',
#   '2010',
#   '2019',
#   '2020',
#   '2014',
#   '2018',
#   '2016',
#   '2014',
#   '2016',
#   '2017'],
#  'Kmt run': [67853,
#   55523,
#   117499,
#   91534,
#   50767,
#   35843,
#   97494,
#   48404,
#   97752,
#   79204,
#   30549,
#   61569,
#   18475,
#   44817,
#   47899,
#   34966,
#   89634,
#   102337,
#   32031,
#   81711],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [nan,
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['668000',
#   '800000',
#   '376000',
#   '514000',
#   '782000',
#   '234000',
#   '461000',
#   '461000',
#   '293000',
#   '249000',
#   '703000',
#   '181000',
#   '340000',
#   '526000',
#   '243000',
#   '563000',
#   '244000',
#   '224000',
#   '293000',
#   '570000'],
#  'Location of car': ['Sector-18, Noida',
#   'M3M Urbana, Golf Course Ext., Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'M3M Urbana, Golf Course Ext., Gurugram',
#   'M3M Urbana, Golf Course Ext., Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Metro Walk, Rohini, New Delhi',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Parsvnath City Mall, Faridabad',
#   'Chhatarpur, Delhi\n',
#   'GIP Mall, Noida',
#   'Metro Walk, Rohini, New Delhi',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Metro Walk, Rohini, New Delhi',
#   'Parsvnath City Mall, Faridabad',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Parsvnath City Mall, Faridabad']}

# %%
url8 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&listingSource=TabFilter&storeCityId=2920&pinId=450001"

# %%
new8 = req.get(url8)
new8
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new8.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n113 Used Cars in Indore - Second Hand Cars for Sale\n\n IndoreBuy a carPopular makesMarutiHyundaiTataHondaRenaultToyotaJeepFordMahindraVolkswagenView all makesPopular ModelsMaruti BalenoHyundai i10Maruti AltoTata TiagoHyundai SantroHyundai i20Maruti SwiftMaruti CiazMaruti DzireHyundai VernaView all modelsBody typeHatchbackSedanSUVLuxury SUVFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Baleno (18)Tata Tiago (7)Hyundai Grand i10 (6)Maruti Swift (5)Maruti Ciaz (5)Hyundai Elite i20 (5)ALL BRANDSMaruti (57)Hyundai (39)Tata (17)Honda (11)Renault (6)Toyota (4)Ford (3)Jeep (3)Mahindra (2)Volkswagen (2)Datsun (1)Skoda (1)Nissan (1)KIA (0)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)MG (0)Volvo (0)Jaguar (0)Budget₹ 2,00,000₹ 15,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All113 Used cars in IndoreSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹53,000off2016 Maruti Alto 800LXIManual41,370 km3rd OwnerPetrolMP-04₹3,550/month ₹45,400 downpayment₹2,27,000₹2,80,000Dewas Naka, Lasudia Mori₹80,000off2019 Tata NEXONXM DIESELManual1,10,321 km1st OwnerDieselMP-09₹9,071/month ₹1,16,000 downpayment₹5,80,000₹6,60,000Dewas Naka, Lasudia MoriNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹39,000off2010 Hyundai i10MAGNA 1.2Manual70,706 km2nd OwnerPetrolMP-04₹3,191/month ₹40,800 downpayment₹2,04,000₹2,43,000Dewas Naka, Lasudia Mori₹51,000off2012 Maruti Swift DzireVXIManual70,713 km1st OwnerPetrolMP-09₹4,645/month ₹59,400 downpayment₹2,97,000₹3,48,000Dewas Naka, Lasudia Mori₹94,000off2018 Maruti SwiftVXIManual47,004 km1st OwnerPetrolMP-09₹7,961/month ₹1,01,800 downpayment₹5,09,000₹6,03,000Dewas Naka, Lasudia MoriUsed cars in Indore by brandMarutiHyundaiTataHondaRenaultToyotaFordJeepVolkswagenMahindraSkodaNissanDatsunMGKIA₹46,000off2015 Hyundai Elite i20MAGNA 1.4 CRDIManual2 km2nd OwnerDieselMP-13₹6,647/month ₹85,000 downpayment₹4,25,000₹4,71,000Dewas Naka, Lasudia Mori₹57,000off2022 Hyundai VENUES 1.2Manual10,506 km1st OwnerPetrolMP-09₹13,248/month ₹1,74,000 downpayment₹8,70,000₹9,27,000Dewas Naka, Lasudia Mori₹77,000off2019 Maruti SwiftVXIManual25,984 km1st OwnerPetrolMP-13₹8,446/month ₹1,08,000 downpayment₹5,40,000₹6,17,000Dewas Naka, Lasudia MoriUsed cars in Indore by body typeHatchbackSedanSUVLuxury SUVLuxury Sedan₹67,000off2022 Maruti Alto K10LXIManual2,266 km1st OwnerPetrolMP-09₹6,976/month ₹89,200 downpayment₹4,46,000₹5,13,000Dewas Naka, Lasudia Mori₹28,000off2011 Maruti Wagon R 1.0LXIManual25,090 km1st OwnerPetrolMP-09₹3,472/month ₹44,400 downpayment₹2,22,000₹2,50,000Dewas Naka, Lasudia Mori₹71,000off2020 Hyundai CretaEX 1.5 PETROLManual38,586 km2nd Ow ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)

# %%
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2016', '2019', '2010', '2012', '2018', '2015', '2022', '2019', '2022', '2011', '2020', '2019', '2020', '2020', '2015', '2019', '2015', '2014', '2018', '2016']
# [[' Maruti', ' Alto', ' 800'], [' Tata', ' NEXON'], [' Hyundai', ' i10'], [' Maruti', ' Swift', ' Dzire'], [' Maruti', ' Swift'], [' Hyundai', ' Elite', ' i20'], [' Hyundai', ' VENUE'], [' Maruti', ' Swift'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Wagon', ' R', ' 1'], [' Hyundai', ' Creta'], [' Maruti', ' Dzire'], [' Tata', ' ALTROZ'], [' Maruti', ' Vitara', ' Brezza'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' Eon'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' Celerio'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Celerio']]
# ['Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori', 'Dewas Naka, Lasudia Mori']
# [['41,370'], ['1,10', ',321'], ['70,706'], ['70,713'], ['47,004'], nan, ['10,506'], ['25,984'], ['2,266'], ['25,090'], ['38,586'], ['69,492'], ['31,690'], ['47,622'], ['57,738'], ['84,957'], ['44,228'], ['25,719'], ['43,031'], ['1,23', ',998']]
# [['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual']]
# ['227000', '580000', '204000', '297000', '509000', '425000', '870000', '540000', '446000', '222000', '1031000', '693000', '646000', '744000', '377000', '297000', '337000', '363000', '316000', '308000']

# %%
dicto8 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto8["Kmt run"]
for i in dicto8["Kmt run"]:
    
    if i:
        a = str(i).replace('[','')
        b = a.replace(' ','')
        c = b.replace(',','')
        d = c.replace(']','')
        e = d.replace("''",'')
        kmt1.append((e.strip("'")))
    else:
        kmt1.append(' ')

dicto8n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto8n
# Out:
# {'Name of Cars': [[' Maruti', ' Alto', ' 800'],
#   [' Tata', ' NEXON'],
#   [' Hyundai', ' i10'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Maruti', ' Swift'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Hyundai', ' VENUE'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Hyundai', ' Creta'],
#   [' Maruti', ' Dzire'],
#   [' Tata', ' ALTROZ'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' Eon'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Celerio'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Celerio']],
#  'Registration Year': ['2016',
#   '2019',
#   '2010',
#   '2012',
#   '2018',
#   '2015',
#   '2022',
#   '2019',
#   '2022',
#   '2011',
#   '2020',
#   '2019',
#   '2020',
#   '2020',
#   '2015',
#   '2019',
#   '2015',
#   '2014',
#   '2018',
#   '2016'],
#  'Kmt run': ['41370',
#   '110321',
#   '70706',
#   '70713',
#   '47004',
#   'nan',
#   '10506',
#   '25984',
#   '2266',
#   '25090',
#   '38586',
#   '69492',
#   '31690',
#   '47622',
#   '57738',
#   '84957',
#   '44228',
#   '25719',
#   '43031',
#   '123998'],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['227000',
#   '580000',
#   '204000',
#   '297000',
#   '509000',
#   '425000',
#   '870000',
#   '540000',
#   '446000',
#   '222000',
#   '1031000',
#   '693000',
#   '646000',
#   '744000',
#   '377000',
#   '297000',
#   '337000',
#   '363000',
#   '316000',
#   '308000'],
#  'Location of car': ['Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori',
#   'Dewas Naka, Lasudia Mori']}

# %%
url9 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=2130&pinId=302001"

# %%
new9 = req.get(url9)
new9
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new9.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n110 Used Cars in Jaipur - Second Hand Cars for Sale\n\n JaipurBuy a carPopular makesMarutiHyundaiHondaTataRenaultDatsunVolkswagenMahindraSkodaFordView all makesPopular ModelsMaruti DzireMaruti SwiftHyundai i20Maruti BalenoHonda AmazeHyundai i10Maruti CiazHonda CityMaruti Wagon RMaruti AltoView all modelsBody typeHatchbackSedanSUVLuxury SUVFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Swift (12)Maruti Baleno (12)Honda Amaze (11)Hyundai Elite i20 (9)Maruti Ciaz (8)Honda City (6)ALL BRANDSMaruti (68)Hyundai (30)Honda (22)Tata (12)Renault (9)Datsun (5)Volkswagen (5)Ford (3)Skoda (3)Mahindra (3)Jeep (2)KIA (1)Nissan (1)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Toyota (0)MG (0)Volvo (0)Jaguar (0)Budget₹ 2,00,000₹ 20,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All110 Used cars in JaipurSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹16,000off2015 Maruti Alto 800LXIManual45,518 km1st OwnerPetrolRJ-14₹3,722/month ₹47,600 downpayment₹2,38,000₹2,54,000Mansarovar₹1,01,000off2021 Maruti Vitara BrezzaVXIManual55,657 km1st OwnerPetrolRJ-05₹11,918/month ₹1,52,400 downpayment₹7,62,000₹8,63,000MansarovarNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹21,500off2011 Maruti Swift DzireLDIManual65,848 km1st OwnerDieselRJ-14₹3,902/month ₹49,900 downpayment₹2,49,500₹2,71,000Mansarovar₹40,000off2016 Maruti Alto 800LXIManual67,039 km1st OwnerPetrolRJ-14₹3,879/month ₹49,600 downpayment₹2,48,000₹2,88,000Mansarovar₹56,000off2015 Maruti SwiftVDI ABSManual81,040 km2nd OwnerDieselRJ-45₹6,553/month ₹83,800 downpayment₹4,19,000₹4,75,000MansarovarUsed cars in Jaipur by brandMarutiHyundaiHondaTataRenaultDatsunVolkswagenFordMahindraSkodaJeepKIANissanToyotaMG₹21,000off2010 Maruti SwiftVDIManual1,04,842 km2nd OwnerDieselRJ-45₹3,722/month ₹47,600 downpayment₹2,38,000₹2,59,000Mansarovar₹86,000off2020 Tata ALTROZXE PETROLManual21,388 km1st OwnerPetrolRJ-45₹8,242/month ₹1,05,400 downpayment₹5,27,000₹6,13,000Mansarovar₹54,000off2012 Maruti Swift DzireVXIManual73,214 km1st OwnerPetrolRJ-14₹5,427/month ₹69,400 downpayment₹3,47,000₹4,01,000MansarovarUsed cars in Jaipur by body typeHatchbackSedanSUVLuxury SUVLuxury Sedan₹57,000off2017 Tata TiagoXTA PETROLAutomatic67,719 km1st OwnerPetrolRJ-14₹6,272/month ₹80,200 downpayment₹4,01,000₹4,58,000Mansarovar₹35,000off2016 Maruti Alto K10VXI AMTAutomatic75,196 km1st OwnerPetrolRJ-40₹4,927/month ₹63,000 downpayment₹3,15,000₹3,50,000Mansarovar₹89,000off2018 Maruti SwiftVXIManual97,229 km1st OwnerPetrolRJ-45₹7,804/month ₹99,800 downpayment₹4,99,000₹5,88,000MansarovarUsed cars in Jaipur by fuel typePetrolDieselCNG₹1,10,000off2021 Maruti  ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)

# %%
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2015', '2021', '2011', '2016', '2015', '2010', '2020', '2012', '2017', '2016', '2018', '2021', '2019', '2015', '2014', '2020', '2011', '2014', '2012', '2012']
# [[' Maruti', ' Alto', ' 800'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Swift', ' Dzire'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Swift'], [' Maruti', ' Swift'], [' Tata', ' ALTROZ'], [' Maruti', ' Swift', ' Dzire'], [' Tata', ' Tiago'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Swift'], [' Maruti', ' Swift'], [' Maruti', ' Dzire'], [' Maruti', ' Swift'], [' Hyundai', ' i10'], [' Maruti', ' Alto'], [' Hyundai', ' i10'], [' Maruti', ' Ertiga'], [' Maruti', ' Swift', ' Dzire'], [' Maruti', ' Swift', ' Dzire']]
# ['Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar', 'Mansarovar']
# [['45,518'], ['55,657'], ['65,848'], ['67,039'], ['81,040'], ['1,04', ',842'], ['21,388'], ['73,214'], ['67,719'], ['75,196'], ['97,229'], ['7,183'], ['64,916'], ['71,098'], ['50,789'], ['28,328'], ['74,496'], ['1,00', ',227'], ['94,554'], ['1,04', ',243']]
# [['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Diesel'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Diesel']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Automatic'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['238000', '762000', '249500', '248000', '419000', '238000', '527000', '347000', '401000', '315000', '499000', '789000', '595000', '416000', '267000', '373000', '219000', '602000', '368000', '366000']

# %%
dicto9 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto9["Kmt run"]
for i in dicto9["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto9n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto9n
# Out:
# {'Name of Cars': [[' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift'],
#   [' Tata', ' ALTROZ'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Tata', ' Tiago'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Dzire'],
#   [' Maruti', ' Swift'],
#   [' Hyundai', ' i10'],
#   [' Maruti', ' Alto'],
#   [' Hyundai', ' i10'],
#   [' Maruti', ' Ertiga'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Maruti', ' Swift', ' Dzire']],
#  'Registration Year': ['2015',
#   '2021',
#   '2011',
#   '2016',
#   '2015',
#   '2010',
#   '2020',
#   '2012',
#   '2017',
#   '2016',
#   '2018',
#   '2021',
#   '2019',
#   '2015',
#   '2014',
#   '2020',
#   '2011',
#   '2014',
#   '2012',
#   '2012'],
#  'Kmt run': [45518,
#   55657,
#   65848,
#   67039,
#   81040,
#   104842,
#   21388,
#   73214,
#   67719,
#   75196,
#   97229,
#   7183,
#   64916,
#   71098,
#   50789,
#   28328,
#   74496,
#   100227,
#   94554,
#   104243],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Diesel']],
#  'Price': ['238000',
#   '762000',
#   '249500',
#   '248000',
#   '419000',
#   '238000',
#   '527000',
#   '347000',
#   '401000',
#   '315000',
#   '499000',
#   '789000',
#   '595000',
#   '416000',
#   '267000',
#   '373000',
#   '219000',
#   '602000',
#   '368000',
#   '366000'],
#  'Location of car': ['Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar',
#   'Mansarovar']}

# %%
url10="https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=777&pinId=700001"

# %%
new10 = req.get(url10)
new10
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new10.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n225 Used Cars in Kolkata - Second Hand Cars for Sale\n\n KolkataBuy a carPopular makesMarutiHyundaiHondaTataMahindraRenaultKIAToyotaFordDatsunView all makesPopular ModelsMaruti AltoHyundai i10Maruti SwiftHonda CityHyundai i20Maruti Wagon RMaruti DzireMaruti CelerioMaruti BalenoHyundai SantroView all modelsBody typeHatchbackSedanSUVLuxury SUVLuxury SedanFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Swift (20)Honda City (16)Maruti Celerio (14)Maruti Swift Dzire (12)Maruti Baleno (12)Maruti Alto 800 (12)ALL BRANDSMaruti (125)Hyundai (80)Honda (38)Tata (20)Mahindra (16)Renault (14)KIA (10)Toyota (10)Ford (7)Datsun (4)Volkswagen (3)Skoda (2)Nissan (2)MG (2)Jeep (1)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Volvo (0)Jaguar (0)Budget₹ 1,00,000₹ 20,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All225 Used cars in KolkataSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New2015 Hyundai VernaFLUIDIC 4S 1.6 VTVT S(O)Manual79,281 km2nd OwnerPetrolWB-02₹6,741/month ₹86,200 downpayment₹4,31,000Barasat, Kolkata₹10,000off2015 Maruti Alto 800LXIManual38,595 km1st OwnerPetrolWB-18₹3,331/month ₹42,600 downpayment₹2,13,000₹2,23,000Barasat, KolkataNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹25,000off2017 Hyundai EonMAGNA+ SEManual42,874 km1st OwnerPetrolWB-06₹4,520/month ₹57,800 downpayment₹2,89,000₹3,14,000Barasat, Kolkata₹21,000off2016 Maruti Alto 800LXIManual27,186 km1st OwnerPetrolWB-26₹4,176/month ₹53,400 downpayment₹2,67,000₹2,88,000Barasat, Kolkata2019 Hyundai Verna1.6 VTVT SXManual26,288 km1st OwnerPetrolWB-08₹12,745/month ₹1,67,400 downpayment₹8,37,000Barasat, KolkataUsed cars in Kolkata by brandMarutiHyundaiHondaTataMahindraRenaultToyotaKIAFordDatsunVolkswagenSkodaNissanMGJeepJaguar2015 Maruti Alto K10VXIManual31,316 km1st OwnerPetrolWB-16₹3,363/month ₹43,000 downpayment₹2,15,000Barasat, Kolkata₹29,000off2015 Maruti BalenoDELTA PETROL 1.2Manual75,441 km1st OwnerPetrolWB-02₹6,084/month ₹77,800 downpayment₹3,89,000₹4,18,000Acropolis Mall, Kolkata2018 Hyundai Elite i20ASTA 1.2Manual66,485 km1st OwnerPetrolWB-08₹8,899/month ₹1,13,800 downpayment₹5,69,000Barasat, KolkataUsed cars in Kolkata by body typeHatchbackSedanSUVLuxury SUVLuxury Sedan2020 Hyundai NEW I20ASTA 1.2 MTManual41,881 km1st OwnerPetrolWB-08₹11,151/month ₹1,42,600 downpayment₹7,13,000Acropolis Mall, Kolkata₹31,000off2010 Hyundai i20MAGNA 1.2Manual87,845 km1st OwnerPetrolWB-06₹2,893/month ₹37,000 downpayment₹1,85,000₹2,16,000Acropolis Mall, Kolkata₹19,000off2010 Maruti SwiftLXIManual71,156 km2nd OwnerPetrolWB-38₹2,502/month ₹32,000 downpayment₹1,60,000₹1,79,000Barasat, ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)

# %%
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2015', '2015', '2017', '2016', '2019', '2015', '2015', '2018', '2020', '2010', '2010', '2018', '2010', '2016', '2019', '2015', '2022', '2018', '2010', '2010']
# [[' Hyundai', ' Verna'], [' Maruti', ' Alto', ' 800'], [' Hyundai', ' Eon'], [' Maruti', ' Alto', ' 800'], [' Hyundai', ' Verna'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Baleno'], [' Hyundai', ' Elite', ' i20'], [' Hyundai', ' NEW', ' I20'], [' Hyundai', ' i20'], [' Maruti', ' Swift'], [' Hyundai', ' Grand', ' i10'], [' Maruti', ' A', ' Star'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Alto', ' 800'], [' Hyundai', ' Eon'], [' Maruti', ' Swift'], [' Maruti', ' Ciaz'], [' Maruti', ' Wagon', ' R'], [' Hyundai', ' i10']]
# ['Barasat, Kolkata', 'Barasat, Kolkata', 'Barasat, Kolkata', 'Barasat, Kolkata', 'Barasat, Kolkata', 'Barasat, Kolkata', 'Acropolis Mall, Kolkata', 'Barasat, Kolkata', 'Acropolis Mall, Kolkata', 'Acropolis Mall, Kolkata', 'Barasat, Kolkata', 'Acropolis Mall, Kolkata', 'Acropolis Mall, Kolkata', 'Barasat, Kolkata', 'Barasat, Kolkata', 'Barasat, Kolkata', 'Barasat, Kolkata', 'Barasat, Kolkata', 'Barasat, Kolkata', 'Acropolis Mall, Kolkata']
# [['79,281'], ['38,595'], ['42,874'], ['27,186'], ['26,288'], ['31,316'], ['75,441'], ['66,485'], ['41,881'], ['87,845'], ['71,156'], ['33,168'], ['54,501'], ['36,270'], ['2,707'], ['19,090'], ['1,775'], ['52,130'], ['76,672'], ['60,585']]
# [['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['431000', '213000', '289000', '267000', '837000', '215000', '389000', '569000', '713000', '185000', '160000', '440000', '135000', '209000', '270000', '191000', '644000', '560000', '137000', '166000']

# %%
dicto10 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto10["Kmt run"]
for i in dicto10["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto10n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto10n
# Out:
# {'Name of Cars': [[' Hyundai', ' Verna'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Hyundai', ' Eon'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Hyundai', ' Verna'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Baleno'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Hyundai', ' NEW', ' I20'],
#   [' Hyundai', ' i20'],
#   [' Maruti', ' Swift'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Maruti', ' A', ' Star'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Hyundai', ' Eon'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Ciaz'],
#   [' Maruti', ' Wagon', ' R'],
#   [' Hyundai', ' i10']],
#  'Registration Year': ['2015',
#   '2015',
#   '2017',
#   '2016',
#   '2019',
#   '2015',
#   '2015',
#   '2018',
#   '2020',
#   '2010',
#   '2010',
#   '2018',
#   '2010',
#   '2016',
#   '2019',
#   '2015',
#   '2022',
#   '2018',
#   '2010',
#   '2010'],
#  'Kmt run': [79281,
#   38595,
#   42874,
#   27186,
#   26288,
#   31316,
#   75441,
#   66485,
#   41881,
#   87845,
#   71156,
#   33168,
#   54501,
#   36270,
#   2707,
#   19090,
#   1775,
#   52130,
#   76672,
#   60585],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['431000',
#   '213000',
#   '289000',
#   '267000',
#   '837000',
#   '215000',
#   '389000',
#   '569000',
#   '713000',
#   '185000',
#   '160000',
#   '440000',
#   '135000',
#   '209000',
#   '270000',
#   '191000',
#   '644000',
#   '560000',
#   '137000',
#   '166000'],
#  'Location of car': ['Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Acropolis Mall, Kolkata',
#   'Barasat, Kolkata',
#   'Acropolis Mall, Kolkata',
#   'Acropolis Mall, Kolkata',
#   'Barasat, Kolkata',
#   'Acropolis Mall, Kolkata',
#   'Acropolis Mall, Kolkata',
#   'Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Barasat, Kolkata',
#   'Acropolis Mall, Kolkata']}

# %%
url11= "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=6356&pinId=682001"

# %%
new11 = req.get(url11)
new11
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new11.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n164 Used Cars in Kochi - Second Hand Cars for Sale\n\n KochiBuy a carPopular makesMarutiHyundaiTataHondaRenaultDatsunMahindraFordVolkswagenNissanView all makesPopular ModelsHyundai i10Maruti AltoHyundai i20Maruti SwiftMaruti BalenoTata TiagoMaruti Wagon RHyundai SantroDatsun Redi GoRenault KwidView all modelsBody typeHatchbackSUVSedanLuxury SUVLuxury SedanFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsHyundai Grand i10 (16)Maruti Swift (13)Maruti Baleno (13)Tata Tiago (12)Hyundai Elite i20 (10)Maruti Alto 800 (10)ALL BRANDSMaruti (70)Hyundai (65)Tata (29)Honda (20)Renault (18)Datsun (12)Mahindra (10)Ford (8)Volkswagen (6)Nissan (4)MG (2)Skoda (1)Jeep (1)Toyota (1)KIA (0)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Volvo (0)Jaguar (0)Budget₹ 1,00,000₹ 20,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All164 Used cars in KochiSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New2011 Hyundai i20MAGNA 1.4 CRDIManual81,095 km2nd OwnerDieselKL-23₹3,801/month ₹48,600 downpayment₹2,43,000Kakkanad, Kochi₹36,000off2020 Tata NEXONXZ PLUS PETROLManual75,840 km1st OwnerPetrolKL-02₹13,994/month ₹1,83,800 downpayment₹9,19,000₹9,55,000Kakkanad, KochiNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility �
], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic']]
# ['243000', '919000', '148000', '295000', '550000', '287000', '417000', '372000', '179000', '319000', '198000', '474000', '698000', '381000', '214000', '237000', '233000', '367000', '371000', '434000']

# %%
dicto11 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto11["Kmt run"]
for i in dicto11["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto11n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto11n
# Out:
# {'Name of Cars': [[' Hyundai', ' i20'],
#   [' Tata', ' NEXON'],
#   [' Maruti', ' Zen', ' Estilo'],
#   [' Hyundai', ' i20'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Celerio'],
#   [' Maruti', ' Celerio'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Hyundai', ' Eon'],
#   [' Hyundai', ' i10'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' Verna'],
#   [' Tata', ' Tiago'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Ritz'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Tata', ' Tiago'],
#   [' Maruti', ' Wagon', ' R', ' 1']],
#  'Registration Year': ['2011',
#   '2020',
#   '2010',
#   '2012',
#   '2015',
#   '2011',
#   '2015',
#   '2017',
#   '2010',
#   '2018',
#   '2010',
#   '2017',
#   '2018',
#   '2018',
#   '2013',
#   '2012',
#   '2011',
#   '2017',
#   '2018',
#   '2018'],
#  'Kmt run': [81095,
#   75840,
#   91626,
#   93134,
#   54780,
#   99490,
#   99277,
#   97978,
#   86618,
#   37518,
#   97307,
#   50347,
#   87005,
#   98088,
#   78187,
#   55837,
#   106880,
#   45376,
#   120667,
#   35649],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic']],
#  'Fuel type': [['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['243000',
#   '919000',
#   '148000',
#   '295000',
#   '550000',
#   '287000',
#   '417000',
#   '372000',
#   '179000',
#   '319000',
#   '198000',
#   '474000',
#   '698000',
#   '381000',
#   '214000',
#   '237000',
#   '233000',
#   '367000',
#   '371000',
#   '434000'],
#  'Location of car': ['Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi',
#   'Kakkanad, Kochi']}

# %%
url12="https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=290&pinId=226001"

# %%
new12 = req.get(url12)
new12
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new12.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n133 Used Cars in Lucknow - Second Hand Cars for Sale\n\n LucknowBuy a carPopular makesMarutiHyundaiHondaToyotaFordTataRenaultMahindraVolkswagenNissanView all makesPopular ModelsHyundai i10Maruti SwiftMaruti Wagon RMaruti DzireHonda CityMaruti BrezzaMaruti AltoHyundai i20Maruti IGNISFord EcosportView all modelsBody typeHatchbackSUVSedanFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Swift (14)Hyundai Grand i10 (11)Honda City (9)Maruti Vitara Brezza (9)Maruti New Wagon-R (8)Ford Ecosport (7)ALL BRANDSMaruti (80)Hyundai (45)Honda (19)Toyota (9)Ford (8)Tata (8)Renault (7)Mahindra (5)Skoda (2)Nissan (2)Volkswagen (2)KIA (1)Datsun (1)BMW (0)Mercedes Benz (0)Audi (0)Jeep (0)Fiat (0)MG (0)Volvo (0)Jaguar (0)Budget₹ 1,50,000₹ 15,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All133 Used cars in LucknowSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New2015 Maruti Swift DzireZXIManual94,408 km2nd OwnerPetrolUP-32₹7,069/month ₹90,400 downpayment₹4,52,000Ansal Golf City, Lucknow₹54,000off2019 Hyundai CretaSX AT 1.6 DIESELAutomatic60,455 km1st OwnerDieselUP-78₹17,222/month ₹2,26,200 downpayment₹11,31,000₹11,85,000Ansal Golf City, LucknowNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility �
= {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto12["Kmt run"]
for i in dicto12["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto12n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto12n
# Out:
# {'Name of Cars': [[' Maruti', ' Swift', ' Dzire'],
#   [' Hyundai', ' Creta'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Hyundai', ' i10'],
#   [' Maruti', ' Swift'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Hyundai', ' i10'],
#   [' Tata', ' Tiago'],
#   [' Hyundai', ' Verna'],
#   [' Hyundai', ' Verna'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Celerio'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Maruti', ' S', ' PRESSO'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' New', ' Wagon'],
#   [' Maruti', ' Alto']],
#  'Registration Year': ['2015',
#   '2019',
#   '2019',
#   '2016',
#   '2011',
#   '2013',
#   '2015',
#   '2017',
#   '2012',
#   '2018',
#   '2017',
#   '2018',
#   '2019',
#   '2014',
#   '2014',
#   '2020',
#   '2018',
#   '2016',
#   '2020',
#   '2022'],
#  'Kmt run': [94408,
#   60455,
#   67829,
#   97063,
#   97351,
#   117343,
#   113638,
#   64362,
#   37947,
#   38017,
#   45853,
#   50588,
#   65772,
#   65187,
#   98693,
#   8449,
#   52419,
#   64794,
#   67952,
#   3890],
#  'Transmission': [['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['452000',
#   '1131000',
#   '576000',
#   '375000',
#   '196000',
#   '291000',
#   '297000',
#   '472000',
#   '196000',
#   '381000',
#   '782000',
#   '732000',
#   '561000',
#   '266000',
#   '392000',
#   '436000',
#   '352000',
#   '627000',
#   '451000',
#   '412000'],
#  'Location of car': ['Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow',
#   'Ansal Golf City, Lucknow']}

# %%
url13 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=2378&pinId=400001"

# %%
new13 = req.get(url13)
new13
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new13.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n632 Used Cars in Mumbai - Second Hand Cars for Sale\n\n MumbaiBuy a carPopular makesMarutiHyundaiHondaTataRenaultToyotaVolkswagenMahindraFordDatsunView all makesPopular ModelsMaruti Wagon RHyundai i20Honda CityHyundai i10Maruti BalenoMaruti DzireMaruti AltoMaruti CelerioHyundai CretaMaruti ErtigaView all modelsBody typeHatchbackSedanSUVLuxury SUVLuxury SedanFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsHonda City (62)Maruti Wagon R 1.0 (62)Maruti Baleno (50)Hyundai Elite i20 (43)Maruti Celerio (35)Hyundai Grand i10 (33)ALL BRANDSMaruti (355)Hyundai (213)Honda (110)Tata (64)Renault (32)Mahindra (24)Toyota (24)Volkswagen (23)Ford (19)Datsun (6)Skoda (5)Jeep (5)Nissan (4)KIA (2)MG (1)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Volvo (0)Jaguar (0)Budget₹ 1,00,000₹ 25,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear All632 Used cars in MumbaiSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New2013 Maruti Swift DzireVDIManual26,698 km1st OwnerDieselMH-05₹11,144/month ₹1,05,800 downpayment₹5,29,000Rupa Renaissance, Navi Mumbai₹1,19,000off2018 Hyundai Verna1.6 VTVT SX OManual61,662 km2nd OwnerPetrolMH-15₹11,761/month ₹1,50,400 downpayment₹7,52,000₹8,71,000Mulund\nNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹29,000off2015 Maruti Swift DzireVXIManual1,10,540 km1st OwnerPetrolMH-46₹7,385/month ₹83,000 downpayment₹4,15,000₹4,44,000Goregaon, Mumbai₹69,000off2020 Tata TiagoXZ PLUS PETROLManual45,638 km1st OwnerPetrolMH-47₹8,086/month ₹1,03,400 downpayment₹5,17,000₹5,86,000Rupa Renaissance, Navi Mumbai₹41,000off2015 Hyundai Grand i10MAGNA 1.2 KAPPA VTVTManual41,378 km1st OwnerPetrolMH-48₹5,630/month ₹72,000 downpayment₹3,60,000₹4,01,000Goregaon, MumbaiUsed cars in Mumbai by brandMarutiHyundaiHondaTataRenaultToyotaVolkswagenMahindraFordSkodaDatsunJeepNissanKIAMGBMWJaguarMercedes BenzFiat₹10,000off2014 Maruti Wagon R 1.0VXIManual78,118 km3rd OwnerCNGMH-02₹5,456/month ₹51,800 downpayment₹2,59,000₹2,69,000Rupa Renaissance, Navi Mumbai₹15,000off2013 Hyundai VernaFLUIDIC 1.6 EX CRDI ATAutomatic87,172 km3rd OwnerDieselMH-48₹8,300/month ₹78,800 downpayment₹3,94,000₹4,09,000Goregaon, Mumbai₹7,000off2017 Tata TiagoXZ PETROLManual48,059 km2nd OwnerPetrolMH-02₹5,677/month ₹72,600 downpayment₹3,63,000₹3,70,000Mulund\nUsed cars in Mumbai by body typeHatchbackSedanSUVLuxury SUVLuxury Sedan₹13,000off2012 Maruti Zen EstiloLXI CNGManual69,120 km2nd OwnerCNGMH-02₹6,967/month ₹37,000 downpayment₹1,85,000₹1,98,000Mulund\n₹14,000off2016 Maruti CelerioZXIManual85,307 km3rd OwnerPetrolMH-03₹4,692/month ₹60,000 downpayment₹3,00,000₹3,14,000Mulund\n₹15,000off2010 Maru ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2013', '2018', '2015', '2020', '2015', '2014', '2013', '2017', '2012', '2016', '2010', '2019', '2014', '2012', '2017', '2020', '2014', '2019', '2015', '2021']
# [[' Maruti', ' Swift', ' Dzire'], [' Hyundai', ' Verna'], [' Maruti', ' Swift', ' Dzire'], [' Tata', ' Tiago'], [' Hyundai', ' Grand', ' i10'], [' Maruti', ' Wagon', ' R', ' 1'], [' Hyundai', ' Verna'], [' Tata', ' Tiago'], [' Maruti', ' Zen', ' Estilo'], [' Maruti', ' Celerio'], [' Maruti', ' Alto', ' K10'], [' Hyundai', ' VENUE'], [' Maruti', ' Swift'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Dzire'], [' Maruti', ' Ciaz'], [' Maruti', ' Wagon', ' R', ' 1'], [' Tata', ' NEXON'], [' Hyundai', ' Elite', ' i20'], [' Tata', ' ALTROZ']]
# ['Rupa Renaissance, Navi Mumbai', 'Mulund\n', 'Goregaon, Mumbai', 'Rupa Renaissance, Navi Mumbai', 'Goregaon, Mumbai', 'Rupa Renaissance, Navi Mumbai', 'Goregaon, Mumbai', 'Mulund\n', 'Mulund\n', 'Mulund\n', 'Rupa Renaissance, Navi Mumbai', 'Mulund\n', 'Mulund\n', 'Mulund\n', 'Rupa Renaissance, Navi Mumbai', 'Rupa Renaissance, Navi Mumbai', 'Rupa Renaissance, Navi Mumbai', 'Mulund\n', 'Rupa Renaissance, Navi Mumbai', 'Mulund\n']
# [['26,698'], ['61,662'], ['1,10', ',540'], ['45,638'], ['41,378'], ['78,118'], ['87,172'], ['48,059'], ['69,120'], ['85,307'], ['59,489'], ['40,462'], ['32,135'], ['27,275'], ['78,569'], ['10,096'], ['76,560'], ['28,058'], ['50,117'], ['10,199']]
# [['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], nan, ['Diesel'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], nan, nan, ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['529000', '752000', '415000', '517000', '360000', '259000', '394000', '363000', '185000', '300000', '146000', '1000800', '370000', '185000', '639000', '1009000', '289000', '618000', '461000', '614500']

# %%
dicto13 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto13["Kmt run"]
for i in dicto13["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto13n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto13n
# Out:
# {'Name of Cars': [[' Maruti', ' Swift', ' Dzire'],
#   [' Hyundai', ' Verna'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Tata', ' Tiago'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Hyundai', ' Verna'],
#   [' Tata', ' Tiago'],
#   [' Maruti', ' Zen', ' Estilo'],
#   [' Maruti', ' Celerio'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Hyundai', ' VENUE'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Dzire'],
#   [' Maruti', ' Ciaz'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Tata', ' NEXON'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Tata', ' ALTROZ']],
#  'Registration Year': ['2013',
#   '2018',
#   '2015',
#   '2020',
#   '2015',
#   '2014',
#   '2013',
#   '2017',
#   '2012',
#   '2016',
#   '2010',
#   '2019',
#   '2014',
#   '2012',
#   '2017',
#   '2020',
#   '2014',
#   '2019',
#   '2015',
#   '2021'],
#  'Kmt run': [26698,
#   61662,
#   110540,
#   45638,
#   41378,
#   78118,
#   87172,
#   48059,
#   69120,
#   85307,
#   59489,
#   40462,
#   32135,
#   27275,
#   78569,
#   10096,
#   76560,
#   28058,
#   50117,
#   10199],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Diesel'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   nan,
#   nan,
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['529000',
#   '752000',
#   '415000',
#   '517000',
#   '360000',
#   '259000',
#   '394000',
#   '363000',
#   '185000',
#   '300000',
#   '146000',
#   '1000800',
#   '370000',
#   '185000',
#   '639000',
#   '1009000',
#   '289000',
#   '618000',
#   '461000',
#   '614500'],
#  'Location of car': ['Rupa Renaissance, Navi Mumbai',
#   'Mulund\n',
#   'Goregaon, Mumbai',
#   'Rupa Renaissance, Navi Mumbai',
#   'Goregaon, Mumbai',
#   'Rupa Renaissance, Navi Mumbai',
#   'Goregaon, Mumbai',
#   'Mulund\n',
#   'Mulund\n',
#   'Mulund\n',
#   'Rupa Renaissance, Navi Mumbai',
#   'Mulund\n',
#   'Mulund\n',
#   'Mulund\n',
#   'Rupa Renaissance, Navi Mumbai',
#   'Rupa Renaissance, Navi Mumbai',
#   'Rupa Renaissance, Navi Mumbai',
#   'Mulund\n',
#   'Rupa Renaissance, Navi Mumbai',
#   'Mulund\n']}

# %%
url14 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&listingSource=TabFilter&storeCityId=134&pinId=201301"

# %%
new14 = req.get(url14)
new14
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(
...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2020', '2019', '2015', '2018', '2019', '2015', '2019', '2019', '2019', '2014', '2019', '2014', '2018', '2010', '2019', '2019', '2018', '2020', '2021', '2014']
# [[' Hyundai', ' AURA'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Swift'], [' Maruti', ' Swift'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Baleno'], [' Honda', ' Amaze'], [' Maruti', ' New', ' Wagon'], [' Maruti', ' Wagon', ' R', ' 1'], [' Toyota', ' Glanza'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Wagon', ' R', ' 1'], [' Honda', ' Amaze'], [' Maruti', ' Alto'], [' Ford', ' Ecosport'], [' Maruti', ' Swift'], [' Renault', ' Kiger'], [' Maruti', ' Alto', ' K10']]
# ['Sector-18, Noida', 'M3M Urbana, Golf Course Ext., Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'M3M Urbana, Golf Course Ext., Gurugram', 'M3M Urbana, Golf Course Ext., Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Spaze Platinum, Sohna Road, Gurugram', 'Chhatarpur, Delhi\n', 'Metro Walk, Rohini, New Delhi', 'Spaze Platinum, Sohna Road, Gurugram', 'Parsvnath City Mall, Faridabad', 'Spaze Platinum, Sohna Road, Gurugram', 'Parsvnath City Mall, Faridabad', 'Chhatarpur, Delhi\n', 'M3M Urbana, Golf Course Ext., Gurugram', 'GIP Mall, Noida', 'Metro Walk, Rohini, New Delhi', 'Metro Walk, Rohini, New Delhi', 'Metro Walk, Rohini, New Delhi', 'Spaze Platinum, Sohna Road, Gurugram']
# [['67,853'], ['55,523'], ['1,17', ',499'], ['91,534'], ['50,767'], ['35,843'], ['97,494'], ['43,184'], ['48,404'], ['97,752'], ['37,778'], ['79,204'], ['30,549'], ['61,569'], ['37,783'], ['18,475'], ['79,371'], ['44,817'], ['45,459'], ['47,899']]
# [nan, ['Diesel'], ['Diesel'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], nan, nan, ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['668000', '800000', '376000', '514000', '782000', '234000', '461000', '636000', '461000', '293000', '777000', '249000', '703000', '181000', '634000', '340000', '629000', '526000', '679000', '243000']

# %%
dicto14 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto14["Kmt run"]
for i in dicto14["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto14n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto14n
# Out:
# {'Name of Cars': [[' Hyundai', ' AURA'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Baleno'],
#   [' Honda', ' Amaze'],
#   [' Maruti', ' New', ' Wagon'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Toyota', ' Glanza'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Honda', ' Amaze'],
#   [' Maruti', ' Alto'],
#   [' Ford', ' Ecosport'],
#   [' Maruti', ' Swift'],
#   [' Renault', ' Kiger'],
#   [' Maruti', ' Alto', ' K10']],
#  'Registration Year': ['2020',
#   '2019',
#   '2015',
#   '2018',
#   '2019',
#   '2015',
#   '2019',
#   '2019',
#   '2019',
#   '2014',
#   '2019',
#   '2014',
#   '2018',
#   '2010',
#   '2019',
#   '2019',
#   '2018',
#   '2020',
#   '2021',
#   '2014'],
#  'Kmt run': [67853,
#   55523,
#   117499,
#   91534,
#   50767,
#   35843,
#   97494,
#   43184,
#   48404,
#   97752,
#   37778,
#   79204,
#   30549,
#   61569,
#   37783,
#   18475,
#   79371,
#   44817,
#   45459,
#   47899],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [nan,
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['668000',
#   '800000',
#   '376000',
#   '514000',
#   '782000',
#   '234000',
#   '461000',
#   '636000',
#   '461000',
#   '293000',
#   '777000',
#   '249000',
#   '703000',
#   '181000',
#   '634000',
#   '340000',
#   '629000',
#   '526000',
#   '679000',
#   '243000'],
#  'Location of car': ['Sector-18, Noida',
#   'M3M Urbana, Golf Course Ext., Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'M3M Urbana, Golf Course Ext., Gurugram',
#   'M3M Urbana, Golf Course Ext., Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Chhatarpur, Delhi\n',
#   'Metro Walk, Rohini, New Delhi',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Parsvnath City Mall, Faridabad',
#   'Spaze Platinum, Sohna Road, Gurugram',
#   'Parsvnath City Mall, Faridabad',
#   'Chhatarpur, Delhi\n',
#   'M3M Urbana, Golf Course Ext., Gurugram',
#   'GIP Mall, Noida',
#   'Metro Walk, Rohini, New Delhi',
#   'Metro Walk, Rohini, New Delhi',
#   'Metro Walk, Rohini, New Delhi',
#   'Spaze Platinum, Sohna Road, Gurugram']}

# %%
url15 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=2423&pinId=411001"

# %%
new15 = req.get(url15)
new15
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new15.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n704 Used Cars in Pune - Second Hand Cars for Sale\n\n PuneBuy a carPopular makesMarutiHyundaiHondaTataRenaultFordVolkswagenMahindraSkodaKIAView all makesPopular ModelsHyundai i10Maruti Wagon RMaruti SwiftMaruti BalenoMaruti AltoHonda CityHyundai i20Maruti CelerioMaruti DzireMaruti CiazView all modelsBody typeHatchbackSedanSUVLuxury SUVLuxury SedanFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Swift (39)Maruti Baleno (39)Honda City (32)Maruti Wagon R 1.0 (32)Hyundai Grand i10 (30)Maruti Celerio (28)ALL BRANDSMaruti (281)Hyundai (165)Honda (87)Tata (47)Renault (34)Volkswagen (18)Ford (17)Mahindra (16)Skoda (10)KIA (9)Toyota (7)Jeep (6)Nissan (4)Datsun (3)MG (2)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Volvo (0)Jaguar (0)Budget₹ 1,50,000₹ 25,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear AllShow More 704 Used cars in PuneSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New2011 Hyundai i10MAGNA 1.2Manual65,515 km1st OwnerPetrolMH-12₹7,945/month ₹59,800 downpayment₹2,99,000Undri, Pune₹20,000off2014 Hyundai EonMAGNA +Manual29,202 km2nd OwnerPetrolMH-04₹3,456/month ₹44,200 downpayment₹2,21,000₹2,41,000Tathawade, PuneNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility 2017 Honda WR-V1.2L I-VTEC VX MTManual79,548 km1st OwnerPetrolMH-14₹10,479/month ₹1,34,000 downpayment₹6,70,000Undri, Pune₹70,000off2020 KIA SELTOSHTK PLUS 1.5Manual34,513 km2nd OwnerPetrolMH-12₹14,816/month ₹1,94,600 downpayment₹9,73,000₹10,43,000Tathawade, Pune2016 Volkswagen PoloTRENDLINE 1.2L PETROLManual67,471 km2nd OwnerPetrolMH-12₹6,929/month ₹88,600 downpayment₹4,43,000Undri, PuneUsed cars in Pune by brandMarutiHyundaiHondaTataRenaultFordVolkswagenMahindraSkodaKIAToyotaJeepNissanDatsunMGMercedes Benz₹7,000off2016 Renault KwidRXT 1.0Manual58,103 km2nd OwnerPetrolMH-20₹4,364/month ₹55,800 downpayment₹2,79,000₹2,86,000Tathawade, Pune₹95,000off2014 Maruti ErtigaVXI CNGManual58,042 km2nd OwnerCNGMH-01₹12,619/month ₹1,19,800 downpayment₹5,99,000₹6,94,000Tathawade, Pune2014 Maruti Eeco7 STRManual47,079 km1st OwnerPetrolMH-14₹6,256/month ₹80,000 downpayment₹4,00,000Undri, PuneUsed cars in Pune by body typeHatchbackSedanSUVLuxury SUVLuxury Sedan₹26,000off2012 Maruti Alto 800LXIManual63,748 km2nd OwnerPetrolMH-48₹3,813/month ₹36,200 downpayment₹1,81,000₹2,07,000Undri, Pune₹30,000off2017 Mahindra XUV500W6Manual90,963 km2nd OwnerDieselMH-04₹12,324/month ₹1,57,600 downpayment₹7,88,000₹8,18,000Tathawade, Pune2019 Hyundai Grand i10SPORTZ 1.2 KAPPA VTVTManual40,352 km1st OwnerPetrolMH-06₹9,071/month ₹1,16,000 downpayment₹5,80,000Undri, PuneUsed cars in Pune by fuel typePetrolDi ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2011', '2014', '2017', '2020', '2016', '2016', '2014', '2014', '2012', '2017', '2019', '2011', '2014', '2021', '2010', '2017', '2017', '2011', '2017', '2016']
# [[' Hyundai', ' i10'], [' Hyundai', ' Eon'], [' Honda', ' WR'], [' KIA', ' SELTOS'], [' Volkswagen', ' Polo'], [' Renault', ' Kwid'], [' Maruti', ' Ertiga'], [' Maruti', ' Eeco'], [' Maruti', ' Alto', ' 800'], [' Mahindra', ' XUV500'], [' Hyundai', ' Grand', ' i10'], [' Hyundai', ' i10'], [' Honda', ' CRV'], [' Nissan', ' MAGNITE'], [' Maruti', ' Wagon', ' R', ' 1'], [' Tata', ' Tiago'], [' Maruti', ' Dzire'], [' Hyundai', ' Eon'], [' Hyundai', ' Elite', ' i20'], [' Maruti', ' Alto', ' K10']]
# ['Undri, Pune', 'Tathawade, Pune', 'Undri, Pune', 'Tathawade, Pune', 'Undri, Pune', 'Tathawade, Pune', 'Tathawade, Pune', 'Undri, Pune', 'Undri, Pune', 'Tathawade, Pune', 'Undri, Pune', 'Tathawade, Pune', 'Tathawade, Pune', 'Undri, Pune', 'Undri, Pune', 'Tathawade, Pune', 'Undri, Pune', 'Tathawade, Pune', 'Undri, Pune', 'Undri, Pune']
# [['65,515'], ['29,202'], ['79,548'], ['34,513'], ['67,471'], ['58,103'], ['58,042'], ['47,079'], ['63,748'], ['90,963'], ['40,352'], ['48,863'], ['84,498'], ['42,454'], ['36,113'], ['61,157'], ['40,277'], ['66,145'], ['1,14', ',848'], ['42,591']]
# [['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['299000', '221000', '670000', '973000', '443000', '279000', '599000', '400000', '181000', '788000', '580000', '205000', '708000', '681000', '200000', '402000', '642000', '181000', '540000', '274000']

# %%
dicto15 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto15["Kmt run"]
for i in dicto15["Kmt run"]:
    
    if i:
        a = str(i).replace('[','')
        b = a.replace(' ','')
        c = b.replace(',','')
        d = c.replace(']','')
        e = d.replace("''",'')
        kmt1.append((e.strip("'")))
    else:
        kmt1.append(' ')
        
dicto15n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto15n
# Out:
# {'Name of Cars': [[' Hyundai', ' i10'],
#   [' Hyundai', ' Eon'],
#   [' Honda', ' WR'],
#   [' KIA', ' SELTOS'],
#   [' Volkswagen', ' Polo'],
#   [' Renault', ' Kwid'],
#   [' Maruti', ' Ertiga'],
#   [' Maruti', ' Eeco'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Mahindra', ' XUV500'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Hyundai', ' i10'],
#   [' Honda', ' CRV'],
#   [' Nissan', ' MAGNITE'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Tata', ' Tiago'],
#   [' Maruti', ' Dzire'],
#   [' Hyundai', ' Eon'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Maruti', ' Alto', ' K10']],
#  'Registration Year': ['2011',
#   '2014',
#   '2017',
#   '2020',
#   '2016',
#   '2016',
#   '2014',
#   '2014',
#   '2012',
#   '2017',
#   '2019',
#   '2011',
#   '2014',
#   '2021',
#   '2010',
#   '2017',
#   '2017',
#   '2011',
#   '2017',
#   '2016'],
#  'Kmt run': ['65515',
#   '29202',
#   '79548',
#   '34513',
#   '67471',
#   '58103',
#   '58042',
#   '47079',
#   '63748',
#   '90963',
#   '40352',
#   '48863',
#   '84498',
#   '42454',
#   '36113',
#   '61157',
#   '40277',
#   '66145',
#   '114848',
#   '42591'],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['299000',
#   '221000',
#   '670000',
#   '973000',
#   '443000',
#   '279000',
#   '599000',
#   '400000',
#   '181000',
#   '788000',
#   '580000',
#   '205000',
#   '708000',
#   '681000',
#   '200000',
#   '402000',
#   '642000',
#   '181000',
#   '540000',
#   '274000'],
#  'Location of car': ['Undri, Pune',
#   'Tathawade, Pune',
#   'Undri, Pune',
#   'Tathawade, Pune',
#   'Undri, Pune',
#   'Tathawade, Pune',
#   'Tathawade, Pune',
#   'Undri, Pune',
#   'Undri, Pune',
#   'Tathawade, Pune',
#   'Undri, Pune',
#   'Tathawade, Pune',
#   'Tathawade, Pune',
#   'Undri, Pune',
#   'Undri, Pune',
#   'Tathawade, Pune',
#   'Undri, Pune',
#   'Tathawade, Pune',
#   'Undri, Pune',
#   'Undri, Pune']}

# %%
url16 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=136&pinId=202124"

# %%
new16 = req.get(url16)
new16
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new16.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\
...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2017', '2011', '2013', '2018', '2018', '2014', '2017', '2018', '2018', '2015', '2013', '2018', '2014', '2015', '2018', '2013', '2017', '2014', '2018', '2014']
# [[' Maruti', ' Swift'], [' Hyundai', ' i10'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' IGNIS'], [' Renault', ' Kwid'], [' Maruti', ' Swift', ' Dzire'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Swift'], [' Hyundai', ' Elite', ' i20'], [' Hyundai', ' Elite', ' i20'], [' Hyundai', ' Verna'], [' Maruti', ' Alto', ' K10'], [' Hyundai', ' i20'], [' Maruti', ' Celerio'], [' Hyundai', ' New', ' Elantra'], [' Maruti', ' Swift'], [' Maruti', ' IGNIS'], [' Honda', ' City'], [' Maruti', ' Dzire'], [' Maruti', ' Swift', ' Dzire']]
# ['Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n', 'Maharishi Puram, Agra\n']
# [['1,24', ',644'], ['40,596'], ['87,208'], ['1,23', ',617'], ['31,124'], ['55,756'], ['1,20', ',160'], ['1,11', ',670'], ['38,600'], ['51,837'], ['50,765'], ['32,992'], ['90,360'], ['35,915'], ['36,899'], ['88,991'], ['77,184'], ['72,953'], ['48,368'], ['1,07', ',539']]
# [['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual']]
# ['391000', '181000', '250000', '373000', '343000', '372000', '651000', '543000', '589000', '461000', '446000', '353400', '317000', '352000', '1242000', '337000', '404000', '568000', '584000', '378000']

# %%
dicto16 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto16["Kmt run"]
for i in dicto16["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto16n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto16n
# Out:
# {'Name of Cars': [[' Maruti', ' Swift'],
#   [' Hyundai', ' i10'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' IGNIS'],
#   [' Renault', ' Kwid'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Swift'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Hyundai', ' Verna'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Hyundai', ' i20'],
#   [' Maruti', ' Celerio'],
#   [' Hyundai', ' New', ' Elantra'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' IGNIS'],
#   [' Honda', ' City'],
#   [' Maruti', ' Dzire'],
#   [' Maruti', ' Swift', ' Dzire']],
#  'Registration Year': ['2017',
#   '2011',
#   '2013',
#   '2018',
#   '2018',
#   '2014',
#   '2017',
#   '2018',
#   '2018',
#   '2015',
#   '2013',
#   '2018',
#   '2014',
#   '2015',
#   '2018',
#   '2013',
#   '2017',
#   '2014',
#   '2018',
#   '2014'],
#  'Kmt run': [124644,
#   40596,
#   87208,
#   123617,
#   31124,
#   55756,
#   120160,
#   111670,
#   38600,
#   51837,
#   50765,
#   32992,
#   90360,
#   35915,
#   36899,
#   88991,
#   77184,
#   72953,
#   48368,
#   107539],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel']],
#  'Price': ['391000',
#   '181000',
#   '250000',
#   '373000',
#   '343000',
#   '372000',
#   '651000',
#   '543000',
#   '589000',
#   '461000',
#   '446000',
#   '353400',
#   '317000',
#   '352000',
#   '1242000',
#   '337000',
#   '404000',
#   '568000',
#   '584000',
#   '378000'],
#  'Location of car': ['Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n',
#   'Maharishi Puram, Agra\n']}

# %%
url17 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3At
...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2010', '2019', '2019', '2015', '2022', '2021', '2019', '2018', '2017', '2014', '2014', '2019', '2020', '2015', '2015', '2022', '2013', '2016', '2013', '2010']
# [[' Hyundai', ' i10'], [' Hyundai', ' VENUE'], [' Maruti', ' Swift'], [' Honda', ' City'], [' Tata', ' TIGOR'], [' Hyundai', ' GRAND', ' I10', ' NIOS'], [' Volkswagen', ' Ameo'], [' Honda', ' Amaze'], [' Datsun', ' Go', ' Plus'], [' Mahindra', ' XUV500'], [' Maruti', ' Swift'], [' Maruti', ' Alto'], [' Volkswagen', ' Polo'], [' Maruti', ' Baleno'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Alto'], [' Maruti', ' Swift'], [' Toyota', ' Etios'], [' Maruti', ' Swift'], [' Maruti', ' Swift']]
# ['Paras Downtown Square, Chandigarh', 'Wave Mall, Ludhiana', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh']
# [['80,727'], ['42,118'], ['1,06', ',184'], ['96,379'], ['44,564'], ['27,381'], ['48,295'], ['31,904'], ['57,422'], ['89,077'], ['78,352'], ['27,760'], ['45,550'], ['52,311'], ['46,785'], ['14,180'], ['90,533'], ['74,075'], ['85,724'], ['92,322']]
# [['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Diesel'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Diesel'], ['Diesel'], ['Diesel'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['170000', '709000', '544000', '493000', '801000', '607000', '499000', '555000', '292000', '541000', '330000', '282000', '494000', '365000', '236000', '398000', '293000', '397000', '309000', '219000']

# %%
dicto17 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto17["Kmt run"]
for i in dicto17["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto17n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto17n
# Out:
# {'Name of Cars': [[' Hyundai', ' i10'],
#   [' Hyundai', ' VENUE'],
#   [' Maruti', ' Swift'],
#   [' Honda', ' City'],
#   [' Tata', ' TIGOR'],
#   [' Hyundai', ' GRAND', ' I10', ' NIOS'],
#   [' Volkswagen', ' Ameo'],
#   [' Honda', ' Amaze'],
#   [' Datsun', ' Go', ' Plus'],
#   [' Mahindra', ' XUV500'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Alto'],
#   [' Volkswagen', ' Polo'],
#   [' Maruti', ' Baleno'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Alto'],
#   [' Maruti', ' Swift'],
#   [' Toyota', ' Etios'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift']],
#  'Registration Year': ['2010',
#   '2019',
#   '2019',
#   '2015',
#   '2022',
#   '2021',
#   '2019',
#   '2018',
#   '2017',
#   '2014',
#   '2014',
#   '2019',
#   '2020',
#   '2015',
#   '2015',
#   '2022',
#   '2013',
#   '2016',
#   '2013',
#   '2010'],
#  'Kmt run': [80727,
#   42118,
#   106184,
#   96379,
#   44564,
#   27381,
#   48295,
#   31904,
#   57422,
#   89077,
#   78352,
#   27760,
#   45550,
#   52311,
#   46785,
#   14180,
#   90533,
#   74075,
#   85724,
#   92322],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol']],
#  'Price': ['170000',
#   '709000',
#   '544000',
#   '493000',
#   '801000',
#   '607000',
#   '499000',
#   '555000',
#   '292000',
#   '541000',
#   '330000',
#   '282000',
#   '494000',
#   '365000',
#   '236000',
#   '398000',
#   '293000',
#   '397000',
#   '309000',
#   '219000'],
#  'Location of car': ['Paras Downtown Square, Chandigarh',
#   'Wave Mall, Ludhiana',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigar
downpayment₹3,63,000₹3,73,000Singanallur, CoimbatoreUsed cars in Coimbatore by body typeHatchbackSUVSedanLuxury SUVLuxury Sedan₹1,14,000off2017 Maruti BalenoZETA CVT PETROL 1.2Automatic44,254 km1st OwnerPetrolTN-13₹9,275/month ₹1,18,600 downpayment₹5,93,000₹7,07,000Singanallur, Coimbatore₹59,000off2016 Maruti BalenoZETA CVT PETROL 1.2Automatic71,475 km1st OwnerPetrolTN-30₹9,494/month ₹1,21,400 downpayment₹6,07,000₹6,66,000Singanallur, Coimbatore₹95,000o ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2017', '2015', '2018', '2022', '2013', '2017', '2015', '2018', '2017', '2016', '2017', '2017', '2018', '2020', '2019', '2018', '2015', '2018', '2021', '2017']
# [[' Tata', ' NEXON'], [' Maruti', ' Swift'], [' Tata', ' NEXON'], [' Volkswagen', ' VIRTUS'], [' Maruti', ' Alto', ' 800'], [' Honda', ' Amaze'], [' Honda', ' Brio'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Baleno'], [' Maruti', ' Baleno'], [' Honda', ' City'], [' Maruti', ' Dzire'], [' Volkswagen', ' Polo'], [' Ford', ' Ecosport'], [' Datsun', ' Go', ' Plus'], [' Renault', ' Kwid'], [' Maruti', ' Celerio'], [' Datsun', ' Go', ' Plus'], [' Skoda', ' Rapid'], [' Maruti', ' Dzire']]
# ['Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore', 'Singanallur, Coimbatore']
# [['88,138'], ['68,094'], ['53,039'], ['14,829'], ['78,476'], ['90,332'], ['1,20', ',127'], ['43,447'], ['44,254'], ['71,475'], ['1,06', ',831'], ['33,550'], ['77,471'], ['26,364'], ['18,689'], ['80,003'], ['1,14', ',529'], ['10,216'], ['39,753'], ['29,753']]
# [['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Automatic'], ['Manual'], ['Automatic'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['657000', '476000', '630000', '1674000', '234500', '444000', '329000', '363000', '593000', '607000', '667000', '615000', '780000', '644000', '490000', '348000', '355000', '415000', '868000', '637000']

# %%
dicto18 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto18["Kmt run"]
for i in dicto18["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto18n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto18n
# Out:
# {'Name of Cars': [[' Tata', ' NEXON'],
#   [' Maruti', ' Swift'],
#   [' Tata', ' NEXON'],
#   [' Volkswagen', ' VIRTUS'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Honda', ' Amaze'],
#   [' Honda', ' Brio'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Baleno'],
#   [' Maruti', ' Baleno'],
#   [' Honda', ' City'],
#   [' Maruti', ' Dzire'],
#   [' Volkswagen', ' Polo'],
#   [' Ford', ' Ecosport'],
#   [' Datsun', ' Go', ' Plus'],
#   [' Renault', ' Kwid'],
#   [' Maruti', ' Celerio'],
#   [' Datsun', ' Go', ' Plus'],
#   [' Skoda', ' Rapid'],
#   [' Maruti', ' Dzire']],
#  'Registration Year': ['2017',
#   '2015',
#   '2018',
#   '2022',
#   '2013',
#   '2017',
#   '2015',
#   '2018',
#   '2017',
#   '2016',
#   '2017',
#   '2017',
#   '2018',
#   '2020',
#   '2019',
#   '2018',
#   '2015',
#   '2018',
#   '2021',
#   '2017'],
#  'Kmt run': [88138,
#   68094,
#   53039,
#   14829,
#   78476,
#   90332,
#   120127,
#   43447,
#   44254,
#   71475,
#   106831,
#   33550,
#   77471,
#   26364,
#   18689,
#   80003,
#   114529,
#   10216,
#   39753,
#   29753],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Manual'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['657000',
#   '476000',
#   '630000',
#   '1674000',
#   '234500',
#   '444000',
#   '329000',
#   '363000',
#   '593000',
#   '607000',
#   '667000',
#   '615000',
#   '780000',
#   '644000',
#   '490000',
#   '348000',
#   '355000',
#   '415000',
#   '868000',
#   '637000'],
#  'Location of car': ['Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore',
#   'Singanallur, Coimbatore']}

# %%
url19 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=2713&pinId=440001"

# %%
new19 = req.get(url19)
new19
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new19.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n138 Used Cars in Nagpur - Second Hand Cars for Sale\n\n NagpurBuy a carPopular makesMarutiHyundaiHondaRenaultNissanFordTataToyotaVolkswagenMahindraView all makesPopular ModelsMaruti AltoMaruti SwiftHyundai i20Maruti Wagon RMaruti BalenoHyundai i10Maruti DzireHonda CityRenault KwidMaruti CelerioView all modelsBody typeHatchbackSedanSUVLuxury SedanFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Swift (16)Maruti Alto 800 (13)Hyundai Elite i20 (11)Maruti Baleno (10)Honda City (8)Maruti Wagon R 1.0 (7)ALL BRANDSMaruti (74)Hyundai (31)Honda (16)Renault (7)Ford (2)Tata (2)Nissan (2)Skoda (1)Mahindra (1)Toyota (1)Volkswagen (1)KIA (0)Datsun (0)BMW (0)Mercedes Benz (0)Audi (0)Jeep (0)Fiat (0)MG (0)Volvo (0)Jaguar (0)Budget₹ 1,50,000₹ 15,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear AllShow More 138 Used cars in NagpurSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹59,000off2011 Maruti SwiftVDIManual87,743 km2nd OwnerDieselMH-31₹3,894/month ₹49,800 downpayment₹2,49,000₹3,08,000Kharbi, Nagpur₹39,000off2018 Renault KwidRXLManual47,552 km3rd OwnerPetrolMH-36₹4,301/month ₹55,000 downpayment₹2,75,000₹3,14,000Kharbi, NagpurNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹31,000off2012 Maruti Alto K10LXIManual96,133 km2nd OwnerPetrolMH-31₹2,518/month ₹32,200 downpayment₹1,61,000₹1,92,000Kharbi, Nagpur₹45,000off2018 Renault KwidRXLManual1,18,789 km1st OwnerPetrolMH-27₹4,238/month ₹54,200 downpayment₹2,71,000₹3,16,000Kharbi, Nagpur₹61,000off2017 Volkswagen PoloHIGHLINE1.2LManual49,118 km1st OwnerPetrolMH-14₹9,697/month ₹1,24,000 downpayment₹6,20,000₹6,81,000Kharbi, NagpurUsed cars in Nagpur by brandMarutiHyundaiHondaRenaultFordNissanTataVolkswagenToyotaMahindraSkodaMGKIADatsun₹9,000off2012 Honda City1.5L I-VTEC S MTManual84,920 km2nd OwnerPetrolMH-01₹4,770/month ₹61,000 downpayment₹3,05,000₹3,14,000Kharbi, Nagpur₹1,14,000off2017 Hyundai i20 Active1.2 BASEManual88,140 km1st OwnerPetrolMH-49₹7,617/month ₹97,400 downpayment₹4,87,000₹6,01,000Kharbi, Nagpur₹16,000off2010 Hyundai i10ERA 1.1Manual47,443 km3rd OwnerPetrolMH-31₹2,690/month ₹34,400 downpayment₹1,72,000₹1,88,000Kharbi, NagpurUsed cars in Nagpur by body typeHatchbackSedanSUVLuxury SedanLuxury SUV₹25,000off2019 Mahindra XUV 3OOW6 1.5 DIESELManual84,242 km1st OwnerDieselMH-49₹13,111/month ₹1,72,200 downpayment₹8,61,000₹8,86,000Kharbi, Nagpur₹58,000off2015 Maruti CelerioVXI CNGManual8,052 km2nd OwnerCNGMH-46₹4,833/month ₹61,800 downpayment₹3,09,000₹3,67,000Kharbi, Nagpur₹1,19,000off2014 Maruti Swift DzireVDIManual78,872 km2nd OwnerDieselMH-03₹6,553/month ₹83,800 downpayment₹4,19,00 ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2011', '2018', '2012', '2018', '2017', '2012', '2017', '2010', '2019', '2015', '2014', '2014', '2014', '2018', '2011', '2019', '2019', '2012', '2019', '2012']
# [[' Maruti', ' Swift'], [' Renault', ' Kwid'], [' Maruti', ' Alto', ' K10'], [' Renault', ' Kwid'], [' Volkswagen', ' Polo'], [' Honda', ' City'], [' Hyundai', ' i20', ' Active'], [' Hyundai', ' i10'], [' Mahindra', ' XUV', ' 3OO'], [' Maruti', ' Celerio'], [' Maruti', ' Swift', ' Dzire'], [' Maruti', ' Swift'], [' Honda', ' City'], [' Maruti', ' Alto', ' 800'], [' Maruti', ' Alto'], [' Hyundai', ' Creta'], [' Maruti', ' New', ' Wagon'], [' Maruti', ' Swift'], [' Maruti', ' Swift'], [' Maruti', ' Swift']]
# ['Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur', 'Kharbi, Nagpur']
# [['87,743'], ['47,552'], ['96,133'], ['1,18', ',789'], ['49,118'], ['84,920'], ['88,140'], ['47,443'], ['84,242'], ['8,052'], ['78,872'], ['89,062'], ['1,09', ',189'], ['79,549'], ['29,904'], ['42,617'], ['52,297'], ['1,00', ',685'], ['48,034'], ['1,05', ',992']]
# [['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], nan, ['Diesel'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Diesel']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['249000', '275000', '161000', '271000', '620000', '305000', '487000', '172000', '861000', '309000', '419000', '370000', '463000', '275000', '156000', '1112000', '440000', '289000', '546000', '353000']

# %%
dicto19 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto19["Kmt run"]
for i in dicto19["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto19n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto19n
# Out:
# {'Name of Cars': [[' Maruti', ' Swift'],
#   [' Renault', ' Kwid'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Renault', ' Kwid'],
#   [' Volkswagen', ' Polo'],
#   [' Honda', ' City'],
#   [' Hyundai', ' i20', ' Active'],
#   [' Hyundai', ' i10'],
#   [' Mahindra', ' XUV', ' 3OO'],
#   [' Maruti', ' Celerio'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Maruti', ' Swift'],
#   [' Honda', ' City'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Maruti', ' Alto'],
#   [' Hyundai', ' Creta'],
#   [' Maruti', ' New', ' Wagon'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift']],
#  'Registration Year': ['2011',
#   '2018',
#   '2012',
#   '2018',
#   '2017',
#   '2012',
#   '2017',
#   '2010',
#   '2019',
#   '2015',
#   '2014',
#   '2014',
#   '2014',
#   '2018',
#   '2011',
#   '2019',
#   '2019',
#   '2012',
#   '2019',
#   '2012'],
#  'Kmt run': [87743,
#   47552,
#   96133,
#   118789,
#   49118,
#   84920,
#   88140,
#   47443,
#   84242,
#   8052,
#   78872,
#   89062,
#   109189,
#   79549,
#   29904,
#   42617,
#   52297,
#   100685,
#   48034,
#   105992],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   nan,
#   ['Diesel'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel']],
#  'Price': ['249000',
#   '275000',
#   '161000',
#   '271000',
#   '620000',
#   '305000',
#   '487000',
#   '172000',
#   '861000',
#   '309000',
#   '419000',
#   '370000',
#   '463000',
#   '275000',
#   '156000',
#   '1112000',
#   '440000',
#   '289000',
#   '546000',
#   '353000'],
#  'Location of car': ['Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur',
#   'Kharbi, Nagpur']}

# %%
url20 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=2598&pinId=422001"

# %%
new20 = req.get(url20)
new20
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new20.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n89 Used Cars in Nashik - Second Hand Cars for Sale\n\n NashikBuy a carPopular makesMarutiHyundaiHondaRenaultFordVolkswagenSkodaDatsunMGNissanView all makesPopular ModelsMaruti Wagon RHyundai i20Renault KwidHyundai i10Maruti DzireMaruti BalenoFord EcosportMaruti SwiftMaruti CelerioMaruti AltoView all modelsBody typeHatchbackSedanSUVFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Wagon R 1.0 (12)Renault Kwid (6)Maruti Swift (5)Maruti Baleno (5)Ford Ecosport (5)Hyundai Grand i10 (4)ALL BRANDSMaruti (40)Hyundai (15)Honda (11)Renault (6)Ford (5)Volkswagen (4)Skoda (3)Datsun (2)Tata (1)Mahindra (1)MG (1)Nissan (1)KIA (0)BMW (0)Mercedes Benz (0)Audi (0)Jeep (0)Fiat (0)Toyota (0)Volvo (0)Jaguar (0)Budget₹ 2,00,000₹ 20,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear AllShow More 89 Used cars in NashikSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹10,000off2016 Tata TiagoXT PETROLManual51,816 km1st OwnerPetrolMH-01₹5,787/month ₹74,000 downpayment₹3,70,000₹3,80,000Adgaon, Nasik₹36,000off2012 Hyundai i20MAGNA (O) 1.2Manual44,933 km2nd OwnerPetrolMH-05₹4,020/month ₹51,400 downpayment₹2,57,000₹2,93,000Adgaon, NasikNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹22,000off2013 Volkswagen VentoHIGHLINE DIESEL 1.6Manual1,10,430 km2nd OwnerDieselMH-04₹4,332/month ₹55,400 downpayment₹2,77,000₹2,99,000Adgaon, Nasik₹44,000off2013 Honda Amaze1.2L I-VTEC SManual61,999 km2nd OwnerPetrolMH-01₹4,473/month ₹57,200 downpayment₹2,86,000₹3,30,000Adgaon, Nasik2019 Hyundai Elite i20SPORTZ PLUS 1.2Manual25,225 km1st OwnerPetrolMH-15₹11,855/month ₹1,51,600 downpayment₹7,58,000Adgaon, NasikUsed cars in Nashik by brandMarutiHyundaiHondaRenaultFordVolkswagenSkodaDatsunTataMGMahindraNissanToyota₹14,000off2014 Maruti CelerioZXI (O)Manual95,988 km1st OwnerPetrolMH-43₹5,568/month ₹71,200 downpayment₹3,56,000₹3,70,000Adgaon, Nasik₹40,000off2013 Honda BrioS MTManual35,781 km2nd OwnerPetrolMH-05₹3,754/month ₹48,000 downpayment₹2,40,000₹2,80,000Adgaon, Nasik₹10,000off2016 Renault KwidRXT 0.8Manual84,647 km1st OwnerPetrolMH-12₹3,801/month ₹48,600 downpayment₹2,43,000₹2,53,000Adgaon, NasikUsed cars in Nashik by body typeHatchbackSedanSUVLuxury SUV₹24,000off2012 Maruti Wagon R 1.0LXIManual80,563 km3rd OwnerPetrolMH-15₹3,738/month ₹47,800 downpayment₹2,39,000₹2,63,000Adgaon, Nasik₹10,000off2014 Ford EcosportTITANIUM 1.0L ECOBOOSTManual80,576 km1st OwnerPetrolMH-03₹7,116/month ₹91,000 downpayment₹4,55,000₹4,65,000Adgaon, Nasik₹78,000off2016 Hyundai Verna1.6 CRDI SXManual57,406 km2nd OwnerDieselMH-01₹10,354/month ₹1,32,400 downpayment₹6,62,000₹7,40,000Adgaon, NasikUsed cars in Nashi ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2016', '2012', '2013', '2013', '2019', '2014', '2013', '2016', '2012', '2014', '2016', '2017', '2018', '2018', '2018', '2018', '2017', '2017', '2017', '2016']
# [[' Tata', ' Tiago'], [' Hyundai', ' i20'], [' Volkswagen', ' Vento'], [' Honda', ' Amaze'], [' Hyundai', ' Elite', ' i20'], [' Maruti', ' Celerio'], [' Honda', ' Brio'], [' Renault', ' Kwid'], [' Maruti', ' Wagon', ' R', ' 1'], [' Ford', ' Ecosport'], [' Hyundai', ' Verna'], [' Maruti', ' Swift'], [' Maruti', ' Wagon', ' R', ' 1'], [' Mahindra', ' TUV300'], [' Maruti', ' Dzire'], [' Maruti', ' Wagon', ' R', ' 1'], [' Skoda', ' Rapid'], [' Maruti', ' Dzire'], [' Maruti', ' Vitara', ' Brezza'], [' Maruti', ' Alto', ' 800']]
# ['Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik', 'Adgaon, Nasik']
# [['51,816'], ['44,933'], ['1,10', ',430'], ['61,999'], ['25,225'], ['95,988'], ['35,781'], ['84,647'], ['80,563'], ['80,576'], ['57,406'], ['79,070'], ['92,055'], ['94,011'], ['57,457'], ['78,901'], ['57,583'], ['88,651'], ['62,590'], ['68,709']]
# [['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], nan, ['Diesel'], ['Diesel'], nan, ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual']]
# ['370000', '257000', '277000', '286000', '758000', '356000', '240000', '243000', '239000', '455000', '662000', '446500', '383000', '730000', '688000', '390000', '695000', '529000', '714000', '289000']

# %%
dicto20 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto20["Kmt run"]
for i in dicto20["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto20n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto20n
# Out:
# {'Name of Cars': [[' Tata', ' Tiago'],
#   [' Hyundai', ' i20'],
#   [' Volkswagen', ' Vento'],
#   [' Honda', ' Amaze'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Maruti', ' Celerio'],
#   [' Honda', ' Brio'],
#   [' Renault', ' Kwid'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Ford', ' Ecosport'],
#   [' Hyundai', ' Verna'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Mahindra', ' TUV300'],
#   [' Maruti', ' Dzire'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Skoda', ' Rapid'],
#   [' Maruti', ' Dzire'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Maruti', ' Alto', ' 800']],
#  'Registration Year': ['2016',
#   '2012',
#   '2013',
#   '2013',
#   '2019',
#   '2014',
#   '2013',
#   '2016',
#   '2012',
#   '2014',
#   '2016',
#   '2017',
#   '2018',
#   '2018',
#   '2018',
#   '2018',
#   '2017',
#   '2017',
#   '2017',
#   '2016'],
#  'Kmt run': [51816,
#   44933,
#   110430,
#   61999,
#   25225,
#   95988,
#   35781,
#   84647,
#   80563,
#   80576,
#   57406,
#   79070,
#   92055,
#   94011,
#   57457,
#   78901,
#   57583,
#   88651,
#   62590,
#   68709],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   nan,
#   ['Diesel'],
#   ['Diesel'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol']],
#  'Price': ['370000',
#   '257000',
#   '277000',
#   '286000',
#   '758000',
#   '356000',
#   '240000',
#   '243000',
#   '239000',
#   '455000',
#   '662000',
#   '446500',
#   '383000',
#   '730000',
#   '688000',
#   '390000',
#   '695000',
#   '529000',
#   '714000',
#   '289000'],
#  'Location of car': ['Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik',
#   'Adgaon, Nasik']}

# %%
url21 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=8184&pinId=800001"

# %%
new21 = req.get(url21)
new21
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new21.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n248 Used Cars in Patna - Second Hand Cars for Sale\n\n PatnaBuy a carPopular makesMarutiHyundaiHondaRenaultMahindraFordTataDatsunNissanKIAView all makesPopular ModelsMaruti DzireMaruti Wagon RMaruti AltoHyundai i10Hyundai i20Maruti SwiftMaruti BalenoHonda AmazeHyundai CretaMaruti CiazView all modelsBody typeHatchbackSUVSedanLuxury SUVFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Dzire (16)Hyundai Elite i20 (14)Maruti Swift (13)Maruti Wagon R 1.0 (13)Maruti Baleno (13)Hyundai Grand i10 (12)ALL BRANDSMaruti (116)Hyundai (58)Honda (19)Renault (13)Ford (8)Tata (8)Mahindra (8)Datsun (7)Nissan (5)KIA (2)Volkswagen (2)Skoda (1)Toyota (1)BMW (0)Mercedes Benz (0)Audi (0)Jeep (0)Fiat (0)MG (0)Volvo (0)Jaguar (0)Budget₹ 1,00,000₹ 20,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear AllShow More 248 Used cars in PatnaSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New2016 Maruti Swift DzireVXIManual54,557 km2nd OwnerPetrolBR-01₹7,695/month ₹98,400 downpayment₹4,92,000Atal Path, Patna₹1,02,000off2015 Mahindra ScorpioS10Manual56,337 km2nd OwnerDieselBR-06₹12,371/month ₹1,58,200 downpayment₹7,91,000₹8,93,000Atal Path, PatnaNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹1,18,000off2020 Mahindra BoleroB6 (O)Manual60,846 km1st OwnerDieselBR-53₹11,292/month ₹1,44,400 downpayment₹7,22,000₹8,40,000Atal Path, Patna₹65,000off2016 Honda BR-V1.5 i- DTEC VXManual1,05,137 km1st OwnerDieselBR-01₹9,040/month ₹1,15,600 downpayment₹5,78,000₹6,43,000Atal Path, Patna₹33,000off2011 Hyundai Santro XingGL PLUSManual94,852 km1st OwnerPetrolBR-01₹2,018/month ₹25,800 downpayment₹1,29,000₹1,62,000Atal Path, PatnaUsed cars in Patna by brandMarutiHyundaiHondaRenaultTataFordMahindraDatsunNissanKIAVolkswagenToyotaSkodaJeep₹34,000off2017 Tata TiagoXM PETROLManual80,310 km1st OwnerPetrolBR-01₹5,224/month ₹66,800 downpayment₹3,34,000₹3,68,000Patna\n₹67,000off2021 Nissan MAGNITEXV MTManual10,938 km2nd OwnerPetrolBR-06₹9,869/month ₹1,26,200 downpayment₹6,31,000₹6,98,000Atal Path, Patna₹47,000off2017 Mahindra XUV500W6Manual87,622 km1st OwnerDieselBR-01₹11,198/month ₹1,43,200 downpayment₹7,16,000₹7,63,000Patna\nUsed cars in Patna by body typeHatchbackSUVSedanLuxury SUVLuxury Sedan₹87,000off2020 Hyundai AURAS 1.2Manual24,220 km1st OwnerPetrolBR-01₹9,384/month ₹1,20,000 downpayment₹6,00,000₹6,87,000Patna\n₹75,000off2017 Maruti Vitara BrezzaVDIManual36,201 km2nd OwnerDieselBR-02₹8,915/month ₹1,14,000 downpayment₹5,70,000₹6,45,000Atal Path, Patna₹85,000off2019 Mahindra XUV 3OOW6 1.5 DIESELManual66,656 km1st OwnerDieselBR-03₹10,588/month ₹1,35,400 downpayment₹6,77,000₹7,62, ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2016', '2015', '2020', '2016', '2011', '2017', '2021', '2017', '2020', '2017', '2019', '2021', '2014', '2021', '2021', '2011', '2015', '2018', '2017', '2018']
# [[' Maruti', ' Swift', ' Dzire'], [' Mahindra', ' Scorpio'], [' Mahindra', ' Bolero'], [' Honda', ' BR'], [' Hyundai', ' Santro', ' Xing'], [' Tata', ' Tiago'], [' Nissan', ' MAGNITE'], [' Mahindra', ' XUV500'], [' Hyundai', ' AURA'], [' Maruti', ' Vitara', ' Brezza'], [' Mahindra', ' XUV', ' 3OO'], [' Mahindra', ' BOLERO', ' NEO'], [' Hyundai', ' Grand', ' i10'], [' Nissan', ' MAGNITE'], [' Maruti', ' Dzire'], [' Maruti', ' Alto', ' K10'], [' Hyundai', ' i20', ' Active'], [' Maruti', ' Swift'], [' Honda', ' City'], [' Maruti', ' Swift']]
# ['Atal Path, Patna', 'Atal Path, Patna', 'Atal Path, Patna', 'Atal Path, Patna', 'Atal Path, Patna', 'Patna\n', 'Atal Path, Patna', 'Patna\n', 'Patna\n', 'Atal Path, Patna', 'Atal Path, Patna', 'Atal Path, Patna', 'Patna\n', 'Patna\n', 'Atal Path, Patna', 'Patna\n', 'Atal Path, Patna', 'Atal Path, Patna', 'Patna\n', 'Patna\n']
# [['54,557'], ['56,337'], ['60,846'], ['1,05', ',137'], ['94,852'], ['80,310'], ['10,938'], ['87,622'], ['24,220'], ['36,201'], ['66,656'], ['29,942'], ['75,368'], ['16,088'], ['42,156'], ['43,340'], ['20,231'], ['62,515'], ['45,271'], ['28,815']]
# [['Petrol'], ['Diesel'], ['Diesel'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Diesel'], ['Diesel'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic']]
# ['492000', '791000', '722000', '578000', '129000', '334000', '631000', '716000', '600000', '570000', '677000', '893000', '307000', '528000', '663000', '171600', '456000', '550000', '635000', '512000']

# %%
dicto21 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto21["Kmt run"]
for i in dicto21["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto21n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto21n
# Out:
# {'Name of Cars': [[' Maruti', ' Swift', ' Dzire'],
#   [' Mahindra', ' Scorpio'],
#   [' Mahindra', ' Bolero'],
#   [' Honda', ' BR'],
#   [' Hyundai', ' Santro', ' Xing'],
#   [' Tata', ' Tiago'],
#   [' Nissan', ' MAGNITE'],
#   [' Mahindra', ' XUV500'],
#   [' Hyundai', ' AURA'],
#   [' Maruti', ' Vitara', ' Brezza'],
#   [' Mahindra', ' XUV', ' 3OO'],
#   [' Mahindra', ' BOLERO', ' NEO'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Nissan', ' MAGNITE'],
#   [' Maruti', ' Dzire'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Hyundai', ' i20', ' Active'],
#   [' Maruti', ' Swift'],
#   [' Honda', ' City'],
#   [' Maruti', ' Swift']],
#  'Registration Year': ['2016',
#   '2015',
#   '2020',
#   '2016',
#   '2011',
#   '2017',
#   '2021',
#   '2017',
#   '2020',
#   '2017',
#   '2019',
#   '2021',
#   '2014',
#   '2021',
#   '2021',
#   '2011',
#   '2015',
#   '2018',
#   '2017',
#   '2018'],
#  'Kmt run': [54557,
#   56337,
#   60846,
#   105137,
#   94852,
#   80310,
#   10938,
#   87622,
#   24220,
#   36201,
#   66656,
#   29942,
#   75368,
#   16088,
#   42156,
#   43340,
#   20231,
#   62515,
#   45271,
#   28815],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic']],
#  'Fuel type': [['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['492000',
#   '791000',
#   '722000',
#   '578000',
#   '129000',
#   '334000',
#   '631000',
#   '716000',
#   '600000',
#   '570000',
#   '677000',
#   '893000',
#   '307000',
#   '528000',
#   '663000',
#   '171600',
#   '456000',
#   '550000',
#   '635000',
#   '512000'],
#  'Location of car': ['Atal Path, Patna',
#   'Atal Path, Patna',
#   'Atal Path, Patna',
#   'Atal Path, Patna',
#   'Atal Path, Patna',
#   'Patna\n',
#   'Atal Path, Patna',
#   'Patna\n',
#   'Patna\n',
#   'Atal Path, Patna',
#   'Atal Path, Patna',
#   'Atal Path, Patna',
#   'Patna\n',
#   'Patna\n',
#   'Atal Path, Patna',
#   'Patna\n',
#   'Atal Path, Patna',
#   'Atal Path, Patna',
#   'Patna\n',
#   'Patna\n']}

# %%
url22 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3At
...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2010', '2019', '2019', '2015', '2022', '2021', '2019', '2018', '2017', '2014', '2014', '2019', '2020', '2015', '2015', '2022', '2013', '2016', '2013', '2010']
# [[' Hyundai', ' i10'], [' Hyundai', ' VENUE'], [' Maruti', ' Swift'], [' Honda', ' City'], [' Tata', ' TIGOR'], [' Hyundai', ' GRAND', ' I10', ' NIOS'], [' Volkswagen', ' Ameo'], [' Honda', ' Amaze'], [' Datsun', ' Go', ' Plus'], [' Mahindra', ' XUV500'], [' Maruti', ' Swift'], [' Maruti', ' Alto'], [' Volkswagen', ' Polo'], [' Maruti', ' Baleno'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Alto'], [' Maruti', ' Swift'], [' Toyota', ' Etios'], [' Maruti', ' Swift'], [' Maruti', ' Swift']]
# ['Paras Downtown Square, Chandigarh', 'Wave Mall, Ludhiana', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh', 'Paras Downtown Square, Chandigarh']
# [['80,727'], ['42,118'], ['1,06', ',184'], ['96,379'], ['44,564'], ['27,381'], ['48,295'], ['31,904'], ['57,422'], ['89,077'], ['78,352'], ['27,760'], ['45,550'], ['52,311'], ['46,785'], ['14,180'], ['90,533'], ['74,075'], ['85,724'], ['92,322']]
# [['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Diesel'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Diesel'], ['Diesel'], ['Diesel'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['170000', '709000', '544000', '493000', '801000', '607000', '499000', '555000', '292000', '541000', '330000', '282000', '494000', '365000', '236000', '398000', '293000', '397000', '309000', '219000']

# %%
dicto22 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto22["Kmt run"]
for i in dicto22["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto22n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto22n
# Out:
# {'Name of Cars': [[' Hyundai', ' i10'],
#   [' Hyundai', ' VENUE'],
#   [' Maruti', ' Swift'],
#   [' Honda', ' City'],
#   [' Tata', ' TIGOR'],
#   [' Hyundai', ' GRAND', ' I10', ' NIOS'],
#   [' Volkswagen', ' Ameo'],
#   [' Honda', ' Amaze'],
#   [' Datsun', ' Go', ' Plus'],
#   [' Mahindra', ' XUV500'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Alto'],
#   [' Volkswagen', ' Polo'],
#   [' Maruti', ' Baleno'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Alto'],
#   [' Maruti', ' Swift'],
#   [' Toyota', ' Etios'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift']],
#  'Registration Year': ['2010',
#   '2019',
#   '2019',
#   '2015',
#   '2022',
#   '2021',
#   '2019',
#   '2018',
#   '2017',
#   '2014',
#   '2014',
#   '2019',
#   '2020',
#   '2015',
#   '2015',
#   '2022',
#   '2013',
#   '2016',
#   '2013',
#   '2010'],
#  'Kmt run': [80727,
#   42118,
#   106184,
#   96379,
#   44564,
#   27381,
#   48295,
#   31904,
#   57422,
#   89077,
#   78352,
#   27760,
#   45550,
#   52311,
#   46785,
#   14180,
#   90533,
#   74075,
#   85724,
#   92322],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol']],
#  'Price': ['170000',
#   '709000',
#   '544000',
#   '493000',
#   '801000',
#   '607000',
#   '499000',
#   '555000',
#   '292000',
#   '541000',
#   '330000',
#   '282000',
#   '494000',
#   '365000',
#   '236000',
#   '398000',
#   '293000',
#   '397000',
#   '309000',
#   '219000'],
#  'Location of car': ['Paras Downtown Square, Chandigarh',
#   'Wave Mall, Ludhiana',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh',
#   'Paras Downtown Square, Chandigarh']}

# %%
url23 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=1674&pinId=390001"

# %%
new23 = req.get(url23)
new23
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new23.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n106 Used Cars in Vadodara - Second Hand Cars for Sale\n\n VadodaraBuy a carPopular makesMarutiHyundaiTataHondaMGMahindraFordVolkswagenRenaultKIAView all makesPopular ModelsMaruti SwiftHyundai i10Maruti BalenoMaruti AltoMaruti Wagon RHyundai i20Hyundai CretaMG HECTORHyundai SantroHonda CityView all modelsBody typeHatchbackSUVSedanLuxury SUVFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Swift (15)Maruti Baleno (9)Hyundai Grand i10 (8)Maruti Alto 800 (6)Maruti Wagon R 1.0 (4)Hyundai Creta (4)ALL BRANDSMaruti (47)Hyundai (26)Tata (11)Honda (7)MG (4)Ford (3)Renault (3)Mahindra (3)Volkswagen (3)KIA (1)Skoda (1)Jeep (1)Datsun (0)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)Toyota (0)Nissan (0)Volvo (0)Jaguar (0)Budget₹ 1,50,000₹ 20,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear AllShow More 106 Used cars in VadodaraSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹26,000off2018 Tata TIGORXT PETROLManual54,479 km1st OwnerPetrolGJ-11₹6,882/month ₹88,000 downpayment₹4,40,000₹4,66,000New Sama, Vadodara₹23,000off2014 Maruti ErtigaZXIManual78,651 km1st OwnerPetrolGJ-07₹9,024/month ₹1,15,400 downpayment₹5,77,000₹6,00,000New Sama, VadodaraNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹85,000off2019 Renault KwidRXT 1.0 AMT (O)Automatic67,081 km1st OwnerPetrolGJ-05₹5,193/month ₹66,400 downpayment₹3,32,000₹4,17,000New Sama, Vadodara2011 Maruti AltoLXIManual82,340 km1st OwnerCNGGJ-06₹2,659/month ₹34,000 downpayment₹1,70,000New Sama, Vadodara2012 Maruti Wagon R 1.0LXIManual1,12,434 km1st OwnerCNGGJ-06₹4,176/month ₹53,400 downpayment₹2,67,000New Sama, VadodaraUsed cars in Vadodara by brandMarutiHyundaiTataHondaMGMahindraRenaultVolkswagenFordJeepSkodaKIANissanToyotaDatsun₹99,000off2014 Honda CityV MT PETROLManual76,800 km2nd OwnerCNGGJ-26₹7,820/month ₹1,00,000 downpayment₹5,00,000₹5,99,000New Sama, Vadodara₹51,000off2018 Maruti CiazDELTA 1.5 SHVS MT PETROLManual63,911 km2nd OwnerPetrolGJ-06₹11,668/month ₹1,49,200 downpayment₹7,46,000₹7,97,000New Sama, Vadodara₹65,000off2017 Hyundai Verna1.6 SX (O) CRDI MTManual56,700 km2nd OwnerDieselGJ-01₹12,471/month ₹1,63,800 downpayment₹8,19,000₹8,84,000New Sama, VadodaraUsed cars in Vadodara by body typeHatchbackSUVSedanLuxury SUVLuxury Sedan₹13,000off2014 Honda City1.5L I-DTEC SVManual97,177 km1st OwnerDieselGJ-06₹7,585/month ₹97,000 downpayment₹4,85,000₹4,98,000New Sama, Vadodara₹5,000off2015 Maruti SwiftVDI ABSManual96,797 km3rd OwnerDieselGJ-06₹6,428/month ₹82,200 downpayment₹4,11,000₹4,16,000New Sama, Vadodara2013 Maruti Alto 800LXIManual88,798 km2nd OwnerPetrolGJ-23₹3,097/month ₹39,600 downpayment ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2018', '2014', '2019', '2011', '2012', '2014', '2018', '2017', '2014', '2015', '2013', '2014', '2022', '2021', '2020', '2010', '2017', '2018', '2013', '2014']
# [[' Tata', ' TIGOR'], [' Maruti', ' Ertiga'], [' Renault', ' Kwid'], [' Maruti', ' Alto'], [' Maruti', ' Wagon', ' R', ' 1'], [' Honda', ' City'], [' Maruti', ' Ciaz'], [' Hyundai', ' Verna'], [' Honda', ' City'], [' Maruti', ' Swift'], [' Maruti', ' Alto', ' 800'], [' Volkswagen', ' Polo'], [' Maruti', ' S', ' PRESSO'], [' Maruti', ' Swift'], [' Hyundai', ' Creta'], [' Hyundai', ' i10'], [' Mahindra', ' XUV500'], [' Maruti', ' Dzire'], [' Maruti', ' Swift'], [' Maruti', ' Swift']]
# ['New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara', 'New Sama, Vadodara']
# [['54,479'], ['78,651'], ['67,081'], ['82,340'], ['1,12', ',434'], ['76,800'], ['63,911'], ['56,700'], ['97,177'], ['96,797'], ['88,798'], ['86,874'], ['13,864'], ['23,941'], ['43,008'], ['85,320'], ['91,086'], ['88,193'], ['80,384'], ['80,580']]
# [['Petrol'], ['Petrol'], ['Petrol'], nan, nan, nan, ['Petrol'], ['Diesel'], ['Diesel'], ['Diesel'], ['Petrol'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], nan, ['Petrol']]
# [['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Automatic'], ['Manual'], ['Manual']]
# ['440000', '577000', '332000', '170000', '267000', '500000', '746000', '819000', '485000', '411000', '198000', '366500', '573000', '673000', '1052000', '219000', '982000', '569000', '375000', '406000']

# %%
dicto23 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto23["Kmt run"]
for i in dicto23["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto23n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto23n
# Out:
# {'Name of Cars': [[' Tata', ' TIGOR'],
#   [' Maruti', ' Ertiga'],
#   [' Renault', ' Kwid'],
#   [' Maruti', ' Alto'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Honda', ' City'],
#   [' Maruti', ' Ciaz'],
#   [' Hyundai', ' Verna'],
#   [' Honda', ' City'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Alto', ' 800'],
#   [' Volkswagen', ' Polo'],
#   [' Maruti', ' S', ' PRESSO'],
#   [' Maruti', ' Swift'],
#   [' Hyundai', ' Creta'],
#   [' Hyundai', ' i10'],
#   [' Mahindra', ' XUV500'],
#   [' Maruti', ' Dzire'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Swift']],
#  'Registration Year': ['2018',
#   '2014',
#   '2019',
#   '2011',
#   '2012',
#   '2014',
#   '2018',
#   '2017',
#   '2014',
#   '2015',
#   '2013',
#   '2014',
#   '2022',
#   '2021',
#   '2020',
#   '2010',
#   '2017',
#   '2018',
#   '2013',
#   '2014'],
#  'Kmt run': [54479,
#   78651,
#   67081,
#   82340,
#   112434,
#   76800,
#   63911,
#   56700,
#   97177,
#   96797,
#   88798,
#   86874,
#   13864,
#   23941,
#   43008,
#   85320,
#   91086,
#   88193,
#   80384,
#   80580],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   nan,
#   nan,
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   nan,
#   ['Petrol']],
#  'Price': ['440000',
#   '577000',
#   '332000',
#   '170000',
#   '267000',
#   '500000',
#   '746000',
#   '819000',
#   '485000',
#   '411000',
#   '198000',
#   '366500',
#   '573000',
#   '673000',
#   '1052000',
#   '219000',
#   '982000',
#   '569000',
#   '375000',
#   '406000'],
#  'Location of car': ['New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara',
#   'New Sama, Vadodara']}

# %%
url24 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=1605&pinId=394101"

# %%
new24 = req.get(url24)
new24
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new24.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n153 Used Cars in Surat - Second Hand Cars for Sale\n\n SuratBuy a carPopular makesMarutiHyundaiHondaRenaultVolkswagenFordMahindraTataToyotaDatsunView all makesPopular ModelsHyundai i10Maruti BalenoMaruti SwiftMaruti DzireMaruti AltoHyundai i20Honda BrioHyundai EonMaruti Wagon RHonda CityView all modelsBody typeHatchbackSedanSUVLuxury SUVFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars under 2 LakhCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Baleno (11)Maruti Swift (10)Hyundai Grand i10 (10)Hyundai i10 (10)Hyundai Eon (6)Honda Brio (6)ALL BRANDSMaruti (61)Hyundai (39)Honda (21)Renault (6)Ford (5)Volkswagen (5)Tata (4)Mahindra (4)Toyota (4)Datsun (2)KIA (1)Nissan (1)BMW (0)Mercedes Benz (0)Skoda (0)Audi (0)Jeep (0)Fiat (0)MG (0)Volvo (0)Jaguar (0)Budget₹ 1,00,000₹ 25,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear AllShow More 153 Used cars in SuratSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹68,000off2014 Hyundai VernaFLUIDIC 1.6 CRDI SX OPTManual94,372 km3rd OwnerDieselGJ-05₹6,147/month ₹78,600 downpayment₹3,93,000₹4,61,000Sachin Magdalla Road, Surat₹44,000off2017 Honda WR-V1.5L I-DTEC VX MTManual47,235 km1st OwnerDieselGJ-05₹11,011/month ₹1,40,800 downpayment₹7,04,000₹7,48,000Sachin Magdalla Road, SuratNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility ₹1,08,000off2018 Honda Amaze1.2L I-VTEC SManual66,535 km3rd OwnerPetrolGJ-27₹7,413/month ₹94,800 downpayment₹4,74,000₹5,82,000Sachin Magdalla Road, Surat₹8,000off2016 Renault KwidRXT 0.8Manual19,712 km1st OwnerPetrolGJ-05₹3,722/month ₹47,600 downpayment₹2,38,000₹2,46,000Sachin Magdalla Road, Surat₹45,000off2017 Mahindra XUV500W10Manual83,180 km1st OwnerDieselGJ-06₹13,354/month ₹1,75,400 downpayment₹8,77,000₹9,22,000Sachin Magdalla Road, SuratUsed cars in Surat by brandMarutiHyundaiHondaRenaultFordVolkswagenMahindraToyotaTataDatsunNissanKIASkodaMGJeep₹80,000off2012 Hyundai i10SPORTZ 1.2Manual59,322 km3rd OwnerPetrolGJ-21₹3,363/month ₹43,000 downpayment₹2,15,000₹2,95,000Sachin Magdalla Road, Surat₹50,000off2017 Datsun Redi GoT (O)Manual76,982 km1st OwnerPetrolGJ-06₹3,081/month ₹39,400 downpayment₹1,97,000₹2,47,000Sachin Magdalla Road, Surat₹37,000off2010 Hyundai i20SPORTZ 1.2Manual56,738 km1st OwnerPetrolGJ-05₹3,597/month ₹46,000 downpayment₹2,30,000₹2,67,000Sachin Magdalla Road, SuratUsed cars in Surat by body typeHatchbackSedanSUVLuxury SUVLuxury Sedan₹88,000off2017 Toyota Fortuner2.8 4X2 ATAutomatic1,16,742 km3rd OwnerDieselGJ-27₹33,043/month ₹4,34,000 downpayment₹21,70,000₹22,58,000Sachin Magdalla Road, Surat₹1,05,000off2016 Maruti SwiftVXIManual87,531 km2nd OwnerPetrolGJ-05₹6,100/month ₹78,000 downpayment₹3,90,000₹4,95,00 ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2014', '2017', '2018', '2016', '2017', '2012', '2017', '2010', '2017', '2016', '2011', '2014', '2012', '2016', '2018', '2018', '2014', '2018', '2010', '2014']
# [[' Hyundai', ' Verna'], [' Honda', ' WR'], [' Honda', ' Amaze'], [' Renault', ' Kwid'], [' Mahindra', ' XUV500'], [' Hyundai', ' i10'], [' Datsun', ' Redi', ' Go'], [' Hyundai', ' i20'], [' Toyota', ' Fortuner'], [' Maruti', ' Swift'], [' Maruti', ' Zen', ' Estilo'], [' Honda', ' City'], [' Maruti', ' Wagon', ' R', ' 1'], [' Maruti', ' Celerio'], [' Hyundai', ' Elite', ' i20'], [' Hyundai', ' Elite', ' i20'], [' Volkswagen', ' Cross', ' Polo'], [' Mahindra', ' KUV', ' 100', ' NXT'], [' Maruti', ' Zen', ' Estilo'], [' Hyundai', ' i20']]
# ['Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat', 'Sachin Magdalla Road, Surat']
# [['94,372'], ['47,235'], ['66,535'], ['19,712'], ['83,180'], ['59,322'], ['76,982'], ['56,738'], ['1,16', ',742'], ['87,531'], ['70,006'], ['94,591'], ['78,259'], ['84,264'], ['71,511'], ['13,141'], ['1,23', ',250'], ['61,528'], ['54,715'], ['62,428']]
# [['Diesel'], ['Diesel'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic']]
# ['393000', '704000', '474000', '238000', '877000', '215000', '197000', '230000', '2170000', '390000', '143000', '409000', '224000', '300000', '562000', '629000', '323000', '325000', '180000', '402000']

# %%
dicto24 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto24["Kmt run"]
for i in dicto24["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto24n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto24n
# Out:
# {'Name of Cars': [[' Hyundai', ' Verna'],
#   [' Honda', ' WR'],
#   [' Honda', ' Amaze'],
#   [' Renault', ' Kwid'],
#   [' Mahindra', ' XUV500'],
#   [' Hyundai', ' i10'],
#   [' Datsun', ' Redi', ' Go'],
#   [' Hyundai', ' i20'],
#   [' Toyota', ' Fortuner'],
#   [' Maruti', ' Swift'],
#   [' Maruti', ' Zen', ' Estilo'],
#   [' Honda', ' City'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' Celerio'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Volkswagen', ' Cross', ' Polo'],
#   [' Mahindra', ' KUV', ' 100', ' NXT'],
#   [' Maruti', ' Zen', ' Estilo'],
#   [' Hyundai', ' i20']],
#  'Registration Year': ['2014',
#   '2017',
#   '2018',
#   '2016',
#   '2017',
#   '2012',
#   '2017',
#   '2010',
#   '2017',
#   '2016',
#   '2011',
#   '2014',
#   '2012',
#   '2016',
#   '2018',
#   '2018',
#   '2014',
#   '2018',
#   '2010',
#   '2014'],
#  'Kmt run': [94372,
#   47235,
#   66535,
#   19712,
#   83180,
#   59322,
#   76982,
#   56738,
#   116742,
#   87531,
#   70006,
#   94591,
#   78259,
#   84264,
#   71511,
#   13141,
#   123250,
#   61528,
#   54715,
#   62428],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic']],
#  'Fuel type': [['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['393000',
#   '704000',
#   '474000',
#   '238000',
#   '877000',
#   '215000',
#   '197000',
#   '230000',
#   '2170000',
#   '390000',
#   '143000',
#   '409000',
#   '224000',
#   '300000',
#   '562000',
#   '629000',
#   '323000',
#   '325000',
#   '180000',
#   '402000'],
#  'Location of car': ['Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat',
#   'Sachin Magdalla Road, Surat']}

# %%
url25 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=1606&pinId=360001"

# %%
new25 = req.get(url25)
new25
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new25.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n149 Used Cars in Rajkot - Second Hand Cars for Sale\n\n RajkotBuy a carPopular makesMarutiHyundaiHondaVolkswagenRenaultMahindraTataNissanFordSkodaView all makesPopular ModelsMaruti AltoHyundai i10Maruti SwiftHyundai i20Honda CityHonda AmazeMaruti BalenoMaruti Wagon RMaruti CiazMaruti DzireView all modelsBody typeHatchbackSedanSUVLuxury SUVFuel typePetrolDieselCNGTransmissionManualAutomaticBudgetCars between 2 Lakh - 5 LakhCars between 5 Lakh - 10 LakhCars above 10 LakhSell a carCar financeHello, Sign inAccount LOG IN/SIGN UP My AppointmentsSELLMy BookingsBUYMy OrdersSell Used CarSell car in New DelhiSell car in BengaluruSell car in ChennaiSell car in HyderabadSell car in MumbaiSell car in PuneSell car in AhmedabadSell car in KolkataSell car in JaipurSell car in ChandigarhBuy Used CarUsed cars in New DelhiUsed cars in MumbaiUsed cars in BangaloreUsed cars in HyderabadUsed cars in AhmedabadUsed cars in GurgaonUsed cars in ChennaiUsed cars in PuneUsed cars in NoidaUsed cars in GhaziabadUsed cars in FaridabadUsed cars in LucknowUsed cars in JaipurUsed cars in KolkataUsed cars in KochiUsed cars in NashikUsed cars in NagpurUsed cars in CoimbatoreUsed cars in IndoreUsed cars in PatnaUsed cars in SuratUsed cars in ChandigarhUsed cars in LudhianaUsed cars in RohtakUsed cars in RajkotUsed cars in VadodaraUsed cars in AgraView and pay challanNEWCar Servicing & RepairNEWResourcesRC Transfer StatusBecome Our partnerFAQMake & ModelSuggestionsMaruti Swift (11)Honda City (9)Hyundai Grand i10 (9)Hyundai Elite i20 (8)Honda Amaze (8)Maruti Baleno (7)ALL BRANDSMaruti (62)Hyundai (30)Honda (27)Volkswagen (10)Renault (5)Ford (3)Tata (3)Nissan (3)Mahindra (2)Datsun (1)Skoda (1)Jeep (1)Toyota (1)KIA (0)BMW (0)Mercedes Benz (0)Audi (0)Fiat (0)MG (0)Volvo (0)Jaguar (0)Budget₹ 2,00,000₹ 20,00,000 MinimumMaximumSuggestionsUnder 3 lakhFrom 3 lakh - 5 lakhFrom 5 lakh - 7 lakhFrom 7 lakh - 10 lakhAbove 10 lakhFuelModel YearFeaturesRTOBody TypeTransmissionOwnersSeatsKms DrivenCARS24 HUBDiscountColorClear AllShow More 149 Used cars in RajkotSort By:Best Match  Best MatchRecently AddedPriceLow to HighHigh to LowKms DrivenLow to HighHigh to LowCars ageNew to OldOld to New₹33,000off2018 Hyundai XcentE+Manual56,674 km2nd OwnerPetrolGJ-37₹7,617/month ₹97,400 downpayment₹4,87,000₹5,20,000Akshar Party, Rajkot₹16,000off2010 Hyundai i10MAGNA 1.2Manual58,135 km2nd OwnerPetrolGJ-10₹3,300/month ₹42,200 downpayment₹2,11,000₹2,27,000Akshar Party, RajkotNeed a car loan?Answer a few questions to  check EMI offers Down  PaymentInterest  RateMonths  EMICheck eligibility �
akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot', 'Akshar Party, Rajkot']
# [['56,674'], ['58,135'], ['80,664'], ['92,407'], ['1,00', ',448'], ['53,673'], ['64,810'], ['1,00', ',785'], ['24,897'], ['56,336'], ['50,954'], ['57,372'], ['99,559'], ['86,604'], ['57,990'], ['75,740'], ['52,314'], ['1,24', ',318'], ['38,866'], ['64,824']]
# [['Petrol'], ['Petrol'], ['Diesel'], ['Diesel'], ['Diesel'], ['Petrol'], ['Petrol'], nan, ['Petrol'], nan, nan, ['Diesel'], ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Petrol'], ['Diesel'], nan, ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['487000', '211000', '427000', '362000', '337000', '406000', '206000', '526000', '766000', '279000', '462000', '769000', '373000', '488000', '460000', '295000', '670000', '344000', '593000', '481000']

# %%
dicto25 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto25["Kmt run"]
for i in dicto25["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto25n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto25n
# Out:
# {'Name of Cars': [[' Hyundai', ' Xcent'],
#   [' Hyundai', ' i10'],
#   [' Honda', ' City'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Maruti', ' Swift'],
#   [' Tata', ' Tiago'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Hyundai', ' VENUE'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Maruti', ' S', ' PRESSO'],
#   [' Hyundai', ' NEW', ' I20'],
#   [' Volkswagen', ' Polo'],
#   [' Volkswagen', ' Polo'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Maruti', ' Swift'],
#   [' Honda', ' Amaze'],
#   [' Maruti', ' Swift']],
#  'Registration Year': ['2018',
#   '2010',
#   '2014',
#   '2016',
#   '2012',
#   '2018',
#   '2010',
#   '2016',
#   '2021',
#   '2012',
#   '2020',
#   '2020',
#   '2015',
#   '2017',
#   '2017',
#   '2017',
#   '2019',
#   '2015',
#   '2019',
#   '2016'],
#  'Kmt run': [56674,
#   58135,
#   80664,
#   92407,
#   100448,
#   53673,
#   64810,
#   100785,
#   24897,
#   56336,
#   50954,
#   57372,
#   99559,
#   86604,
#   57990,
#   75740,
#   52314,
#   124318,
#   38866,
#   64824],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Diesel'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   nan,
#   nan,
#   ['Diesel'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Diesel'],
#   nan,
#   ['Petrol']],
#  'Price': ['487000',
#   '211000',
#   '427000',
#   '362000',
#   '337000',
#   '406000',
#   '206000',
#   '526000',
#   '766000',
#   '279000',
#   '462000',
#   '769000',
#   '373000',
#   '488000',
#   '460000',
#   '295000',
#   '670000',
#   '344000',
#   '593000',
#   '481000'],
#  'Location of car': ['Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot',
#   'Akshar Party, Rajkot']}

# %%
url26 = "https://www.cars24.com/buy-used-car?f=make%3A%3D%3Ahyundai%3AOR%3Amake%3A%3D%3Amaruti%3AOR%3Amake%3A%3D%3Atata%3AOR%3Amake%3A%3D%3Ahonda%3AOR%3Amake%3A%3D%3Arenault%3AOR%3Amake%3A%3D%3Atoyota%3AOR%3Amake%3A%3D%3Aford%3AOR%3Amake%3A%3D%3Amahindra%3AOR%3Amake%3A%3D%3Avolkswagen%3AOR%3Amake%3A%3D%3Adatsun%3AOR%3Amake%3A%3D%3Akia%3AOR%3Amake%3A%3D%3Anissan%3AOR%3Amake%3A%3D%3Ajeep%3AOR%3Amake%3A%3D%3Askoda&sort=bestmatch&serveWarrantyCount=true&gaId=148626934.1699693409&storeCityId=33&pinId=124001"

# %%
new26 = req.get(url26)
new26
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(new26.text)
soup.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\
,000 downpayment₹3,65,000₹3,94,000Parsvnath City Mall, FaridabadUsed cars in Rohtak by brandMarutiHyundaiTataToyotaHondaNissanVolkswagenRenaultDatsunFord₹21,000off2021 Tata ALTROZXE PETROLManual20,955 km1st OwnerPetrolHR-08₹8,336/month ₹1,06,600 downpayment₹5,33,000₹5,54,000Parsvnath City Mall, Faridabad₹22,000off2017 Hyundai Elite i20ASTA 1.2 (O)Manual66,802 km2nd OwnerCNGHR-36₹8,884/month ₹1,13,600 downpayment₹5,68,000₹5,90,000Sector 33, Rohtak₹88,300off2022 Hyundai NEW I20SPORTZ 1.2 MTManual12,181 km1st OwnerPetrolHR-26₹11,037/month ₹1,41,140 downpayment₹7,05,700₹7,94,000Sector 33, RohtakUsed cars in Rohtak by body typeHatchbackSUVSedan2019 Maruti BalenoZETA PETROL 1.2Manual22,963 km2nd OwnerPetrolHR-26₹9,650/month ₹1,23,400 downpayment₹6,17,000Parsvnath City Mall, Faridabad₹90,000off2019 Hyundai XcentS 1.2Manual50,971 km1st OwnerPetrolHR-51₹7,257/month ₹92,800 downpayment₹4,64,000₹5,54,000Parsvnath City Mall, Faridabad₹53,000off2017 Maruti BalenoZETA PETROL 1.2Manual56,740 km1st OwnerPetrolHR-26₹7,726/month ₹98,800 downpayment₹4,94,000₹5,47,000 ...

# %%
Year=[]
car_name=[]
Add = []
Kmt=[]
fuel=[]
Trans=[]
Price = []
for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= r"\b\d{4}\b"
    regex= re.findall(pattern,year)
    if regex:
        Year.append(regex[0])
    else:
        Year.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    year = i.find('h3',class_='_2lmIw').text
    pattern= " \w+"
    regex= re.findall(pattern,year)
    if regex:
        car_name.append(regex)
    else:
        car_name.append(np.nan)

for i in soup.find_all('div',class_="_2z-Yu"):
    add = i.find('span',class_="_3DYbK")
    if add:
        Add.append(add.text)
    else:
        Add.append(np.nan)
Kmt=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"\d{1,3},\d{2,3}|[,]\d{1,3}"
    regex= re.findall(pattern,kmt)
    if regex:
        Kmt.append(regex)
    else:
        Kmt.append(np.nan)

fuel=[]
for i in soup.find_all('div',class_="_2z-Yu"):
    kmt = i.find('ul',class_='_13yb6').text
    pattern= r"Petrol|Diesel"
    regex= re.findall(pattern,kmt)
    if regex:
        fuel.append(regex)
    else:
        fuel.append(np.nan)



for i in soup.find_all('div',class_="_2z-Yu"):
    trans = i.find('ul',class_='_1hOnS').text
    pattern= r"Manual|Automatic"
    regex= re.findall(pattern,trans)
    if regex:
        Trans.append(regex)
    else:
        Trans.append(np.nan)


for i in soup.find_all('div',class_="_2z-Yu"):
    price= i.find('div',class_="_18ToE").text
    yoo = price.split("₹")[1].replace(",","")
    Price.append(yoo)
    
    
print(Year)
print(car_name)
print(Add)
print(Kmt)
print(fuel)
print(Trans)
print(Price)
# Out:
# ['2011', '2012', '2015', '2022', '2017', '2021', '2017', '2022', '2019', '2019', '2017', '2018', '2013', '2019', '2010', '2014', '2023', '2017', '2015', '2011']
# [[' Hyundai', ' i20'], [' Maruti', ' Swift', ' Dzire'], [' Honda', ' City'], [' Tata', ' PUNCH'], [' Maruti', ' Wagon', ' R', ' 1'], [' Tata', ' ALTROZ'], [' Hyundai', ' Elite', ' i20'], [' Hyundai', ' NEW', ' I20'], [' Maruti', ' Baleno'], [' Hyundai', ' Xcent'], [' Maruti', ' Baleno'], [' Maruti', ' Wagon', ' R', ' 1'], [' Hyundai', ' Santro', ' Xing'], [' Maruti', ' Alto', ' K10'], [' Maruti', ' Zen', ' Estilo'], [' Hyundai', ' Grand', ' i10'], [' Maruti', ' BREZZA'], [' Maruti', ' Celerio'], [' Hyundai', ' Grand', ' i10'], [' Maruti', ' Swift']]
# ['Parsvnath City Mall, Faridabad', 'Sector 33, Rohtak', 'Parsvnath City Mall, Faridabad', 'Parsvnath City Mall, Faridabad', 'Parsvnath City Mall, Faridabad', 'Parsvnath City Mall, Faridabad', 'Sector 33, Rohtak', 'Sector 33, Rohtak', 'Parsvnath City Mall, Faridabad', 'Parsvnath City Mall, Faridabad', 'Parsvnath City Mall, Faridabad', 'Sector 33, Rohtak', 'Parsvnath City Mall, Faridabad', 'Parsvnath City Mall, Faridabad', 'Sector 33, Rohtak', 'Parsvnath City Mall, Faridabad', 'Parsvnath City Mall, Faridabad', 'Parsvnath City Mall, Faridabad', 'Sector 33, Rohtak', 'Parsvnath City Mall, Faridabad']
# [['89,507'], ['93,869'], ['24,569'], ['21,566'], ['71,802'], ['20,955'], ['66,802'], ['12,181'], ['22,963'], ['50,971'], ['56,740'], ['78,642'], ['61,788'], ['54,914'], ['56,172'], ['26,218'], ['11,948'], ['1,18', ',486'], ['90,358'], ['81,771']]
# [['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], nan, ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], nan, ['Petrol'], nan, ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol'], ['Petrol']]
# [['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Manual'], ['Automatic'], ['Manual'], ['Manual'], ['Manual'], ['Manual']]
# ['230000', '263000', '482000', '617000', '365000', '533000', '568000', '705700', '617000', '464000', '494000', '361000', '201000', '327000', '115000', '458000', '1190000', '325000', '351000', '189000']

# %%
dicto26 = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':Kmt,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}

# %%
kmt1 = []
dicto26["Kmt run"]
for i in dicto26["Kmt run"]:
    a = str(i).replace('[','')
    b = a.replace(' ','')
    c = b.replace(',','')
    d = c.replace(']','')
    e = d.replace("''",'')
    kmt1.append(int(e.strip("'")))

dicto26n = {'Name of Cars':car_name,'Registration Year':Year,'Kmt run':kmt1,'Transmission':Trans,'Fuel type':fuel,'Price':Price,'Location of car':Add}
dicto26n
# Out:
# {'Name of Cars': [[' Hyundai', ' i20'],
#   [' Maruti', ' Swift', ' Dzire'],
#   [' Honda', ' City'],
#   [' Tata', ' PUNCH'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Tata', ' ALTROZ'],
#   [' Hyundai', ' Elite', ' i20'],
#   [' Hyundai', ' NEW', ' I20'],
#   [' Maruti', ' Baleno'],
#   [' Hyundai', ' Xcent'],
#   [' Maruti', ' Baleno'],
#   [' Maruti', ' Wagon', ' R', ' 1'],
#   [' Hyundai', ' Santro', ' Xing'],
#   [' Maruti', ' Alto', ' K10'],
#   [' Maruti', ' Zen', ' Estilo'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Maruti', ' BREZZA'],
#   [' Maruti', ' Celerio'],
#   [' Hyundai', ' Grand', ' i10'],
#   [' Maruti', ' Swift']],
#  'Registration Year': ['2011',
#   '2012',
#   '2015',
#   '2022',
#   '2017',
#   '2021',
#   '2017',
#   '2022',
#   '2019',
#   '2019',
#   '2017',
#   '2018',
#   '2013',
#   '2019',
#   '2010',
#   '2014',
#   '2023',
#   '2017',
#   '2015',
#   '2011'],
#  'Kmt run': [89507,
#   93869,
#   24569,
#   21566,
#   71802,
#   20955,
#   66802,
#   12181,
#   22963,
#   50971,
#   56740,
#   78642,
#   61788,
#   54914,
#   56172,
#   26218,
#   11948,
#   118486,
#   90358,
#   81771],
#  'Transmission': [['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Automatic'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual'],
#   ['Manual']],
#  'Fuel type': [['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   nan,
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol'],
#   ['Petrol']],
#  'Price': ['230000',
#   '263000',
#   '482000',
#   '617000',
#   '365000',
#   '533000',
#   '568000',
#   '705700',
#   '617000',
#   '464000',
#   '494000',
#   '361000',
#   '201000',
#   '327000',
#   '115000',
#   '458000',
#   '1190000',
#   '325000',
#   '351000',
#   '189000'],
#  'Location of car': ['Parsvnath City Mall, Faridabad',
#   'Sector 33, Rohtak',
#   'Parsvnath City Mall, Faridabad',
#   'Parsvnath City Mall, Faridabad',
#   'Parsvnath City Mall, Faridabad',
#   'Parsvnath City Mall, Faridabad',
#   'Sector 33, Rohtak',
#   'Sector 33, Rohtak',
#   'Parsvnath City Mall, Faridabad',
#   'Parsvnath City Mall, Faridabad',
#   'Parsvnath City Mall, Faridabad',
#   'Sector 33, Rohtak',
#   'Parsvnath City Mall, Faridabad',
#   'Parsvnath City Mall, Faridabad',
#   'Sector 33, Rohtak',
#   'Parsvnath City Mall, Faridabad',
#   'Parsvnath City Mall, Faridabad',
#   'Parsvnath City Mall, Faridabad',
#   'Sector 33, Rohtak',
#   'Parsvnath City Mall, Faridabad']}

# %% [markdown]
# #### Creating Data Frame using pandas

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(dicton)
df2 = pd.DataFrame(dicto2n)
df3 = pd.DataFrame(dicto3n)
df4 = pd.DataFrame(dicto4n)
df5 = pd.DataFrame(dicto5n)
df6 = pd.DataFrame(dicto6n)
df7 = pd.DataFrame(dicto7n)
df8 = pd.DataFrame(dicto8n)
df9 = pd.DataFrame(dicto9n)
df10 = pd.DataFrame(dicto10n)
df11 = pd.DataFrame(dicto11n)
df12 = pd.DataFrame(dicto12n)
df13 = pd.DataFrame(dicto13n)
df14 = pd.DataFrame(dicto14n)
df15 = pd.DataFrame(dicto15n)
df16 = pd.DataFrame(dicto16n)
df17 = pd.DataFrame(dicto17n)
df18 = pd.DataFrame(dicto18n)
df19 = pd.DataFrame(dicto19n)
df20 = pd.DataFrame(dicto20n)
df21 = pd.DataFrame(dicto21n)
df22 = pd.DataFrame(dicto22n)
df23 = pd.DataFrame(dicto23n)
df24 = pd.DataFrame(dicto24n)
df25 = pd.DataFrame(dicto25n)
df26 = pd.DataFrame(dicto26n)

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26],axis=0,ignore_index=True)

# %%
df
# Out:
#                  Name of Cars Registration Year Kmt run Transmission  \
# 0            [ Hyundai,  i10]              2010   57942     [Manual]
# 1    [ Hyundai,  Grand,  i10]              2016   75568     [Manual]
# 2            [ Maruti,  Ciaz]              2021   41362     [Manual]
# 3               [ Honda,  WR]              2017   53535     [Manual]
# 4          [ Maruti,  Baleno]              2017   41260  [Automatic]
# ..                        ...               ...     ...          ...
# 515  [ Hyundai,  Grand,  i10]              2014   26218  [Automatic]
# 516        [ Maruti,  BREZZA]              2023   11948     [Manual]
# 517       [ Maruti,  Celerio]              2017  118486     [Manual]
# 518  [ Hyundai,  Grand,  i10]              2015   90358     [Manual]
# 519         [ Maruti,  Swift]              2011   81771     [Manual]
#
#     Fuel type    Price                 Location of car
# 0    [Petrol]   247000              Attapur, Hyderabad
# 1    [Petrol]   453000              Attapur, Hyderabad
# 2    [Petrol]   819000             Kompally, Hyderabad
# 3    [Diesel]   661000           Bachupally, Hyderabad
# 4    [Petrol]   591000   Vanasthalipuram, Hyderabad.\n
# ..        ...      ...                             ...
# 515  [Petrol]   458000  Parsvnath City Mall, Faridabad
# 516  [Petrol]  1190000  Parsvnath City Mall, Faridabad
# 517  [Petrol]   325000  Parsvnath City Mall, Faridabad
# 518  [Petrol]   351000               Sector 33, Rohtak
# 519  [Petrol]   189000  Parsvnath City Mall, Faridabad
#
# [520 rows x 7 columns]

# %% [markdown]
# #### Handling with structural errors

# %%
#For removing []for transmission colum
df['Transmission'] = df['Transmission'].apply(lambda x: x[0])

#For removing [] for fuel type column
def clean_fuel_type(fuel_list):
    if isinstance(fuel_list, list):
        return fuel_list[0]
    else:
        return fuel_list
df['Fuel type'] = df['Fuel type'].apply(clean_fuel_type)

#For creating one more column by extracting 
df['Brand']=[i[0] for i in df['Name of Cars']]

#For removing [] from them
df['Name Of Cars'] = [" ".join(i[0::]) for i in df['Name of Cars']]

#For new column order
new_order = ['Name Of Cars', 'Brand', 'Registration Year','Transmission','Fuel type','Kmt run','Price','Location of car','Name of Cars']
df = df.reindex(columns=new_order)

#For dropping column
df.drop('Name of Cars',axis=1,inplace=True)

#for removing \n from location column
df['Location of car'] = df['Location of car'].replace('.\n','',regex=True)


#to convert nan=np.nan
df["Kmt run"] = df["Kmt run"].replace("nan",np.nan)

# %%
df
# Out:
#              Name Of Cars     Brand Registration Year Transmission Fuel type  \
# 0            Hyundai  i10   Hyundai              2010       Manual    Petrol
# 1     Hyundai  Grand  i10   Hyundai              2016       Manual    Petrol
# 2            Maruti  Ciaz    Maruti              2021       Manual    Petrol
# 3               Honda  WR     Honda              2017       Manual    Diesel
# 4          Maruti  Baleno    Maruti              2017    Automatic    Petrol
# ..                    ...       ...               ...          ...       ...
# 515   Hyundai  Grand  i10   Hyundai              2014    Automatic    Petrol
# 516        Maruti  BREZZA    Maruti              2023       Manual    Petrol
# 517       Maruti  Celerio    Maruti              2017       Manual    Petrol
# 518   Hyundai  Grand  i10   Hyundai              2015       Manual    Petrol
# 519         Maruti  Swift    Maruti              2011       Manual    Petrol
#
#     Kmt run    Price                 Location of car
# 0     57942   247000              Attapur, Hyderabad
# 1     75568   453000              Attapur, Hyderabad
# 2     41362   819000             Kompally, Hyderabad
# 3     53535   661000           Bachupally, Hyderabad
# 4     41260   591000      Vanasthalipuram, Hyderabad
# ..      ...      ...                             ...
# 515   26218   458000  Parsvnath City Mall, Faridabad
# 516   11948  1190000  Parsvnath City Mall, Faridabad
# 517  118486   325000  Parsvnath City Mall, Faridabad
# 518   90358   351000               Sector 33, Rohtak
# 519   81771   189000  Parsvnath City Mall, Faridabad
#
# [520 rows x 8 columns]

# %% [markdown]
# #### Handling with missing values

# %%
df.isna().sum()
# Out:
# Name Of Cars          0
# Brand                 0
# Registration Year     0
# Transmission          0
# Fuel type            35
# Kmt run               1
# Price                 0
# Location of car       2
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# Name Of Cars         0
# Brand                0
# Registration Year    0
# Transmission         0
# Fuel type            0
# Kmt run              0
# Price                0
# Location of car      0
# dtype: int64

# %%
df.shape
# Out:
# (482, 8)

# %% [markdown]
# #### Handling with Duplicate values

# %%
df.duplicated().sum()
# Out:
# 68

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %%
df.shape
# Out:
# (414, 8)

# %% [markdown]
# #### Handling with Typecasting

# %%
df.dtypes
# Out:
# Name Of Cars         object
# Brand                object
# Registration Year    object
# Transmission         object
# Fuel type            object
# Kmt run              object
# Price                object
# Location of car      object
# dtype: object

# %%
df['Registration Year'] = df['Registration Year'].astype('int32')
df['Kmt run'] = df['Kmt run'].astype('int64')
df['Price'] = df['Price'].astype('int64')

# %%
df.dtypes
# Out:
# Name Of Cars         object
# Brand                object
# Registration Year     int32
# Transmission         object
# Fuel type            object
# Kmt run               int64
# Price                 int64
# Location of car      object
# dtype: object

# %% [markdown]
# #### Handling with Incorrect Format of the data (Invalid Values, Columns)

# %%
df['City Name'] = [i.split(",")[-1] for i in df['Location of car']]


new = []
for i in df['Location of car']:
    if ',' in i:
        new.append(i.split(",")[0])
    else:
        new.append(i)
        
df['Location_of_car'] = new

# %%
df['Location of car'] = df['Location of car'].str.strip().replace(" Benga...","Bengaluru")
df['City Name'] = df['City Name'].str.strip().replace("Benga...","Bengaluru")
df['City Name'] = df['City Name'].str.strip().replace("Chenna","Chennai")
df['City Name'] = df['City Name'].str.strip().replace("Patn","Patna")
df['City Name'] = df['City Name'].str.strip().replace("Agr","Agra")
df['City Name'] = df['City Name'].str.strip().replace("Mansarovar","Jaipur")
df['City Name'] = df['City Name'].str.strip().replace("Lasudia Mori","Indore")
df['City Name'] = df['City Name'].str.strip().replace("Navalur","Chennai")
df['City Name'] = df['City Name'].str.strip().replace("Sonnappanahall","Bengaluru")
df['City Name'] = df['City Name'].str.strip().replace("Mulun","Mumbai")

# %%
df.drop('Location of car',axis=1,inplace=True)

# %%
df
# Out:
#              Name Of Cars     Brand  Registration Year Transmission Fuel type  \
# 0            Hyundai  i10   Hyundai               2010       Manual    Petrol
# 1     Hyundai  Grand  i10   Hyundai               2016       Manual    Petrol
# 2            Maruti  Ciaz    Maruti               2021       Manual    Petrol
# 3               Honda  WR     Honda               2017       Manual    Diesel
# 4          Maruti  Baleno    Maruti               2017    Automatic    Petrol
# ..                    ...       ...                ...          ...       ...
# 409   Hyundai  Grand  i10   Hyundai               2014    Automatic    Petrol
# 410        Maruti  BREZZA    Maruti               2023       Manual    Petrol
# 411       Maruti  Celerio    Maruti               2017       Manual    Petrol
# 412   Hyundai  Grand  i10   Hyundai               2015       Manual    Petrol
# 413         Maruti  Swift    Maruti               2011       Manual    Petrol
#
#      Kmt run    Price  City Name      Location_of_car
# 0      57942   247000  Hyderabad              Attapur
# 1      75568   453000  Hyderabad              Attapur
# 2      41362   819000  Hyderabad             Kompally
# 3      53535   661000  Hyderabad           Bachupally
# 4      41260   591000  Hyderabad      Vanasthalipuram
# ..       ...      ...        ...                  ...
# 409    26218   458000  Faridabad  Parsvnath City Mall
# 410    11948  1190000  Faridabad  Parsvnath City Mall
# 411   118486   325000  Faridabad  Parsvnath City Mall
# 412    90358   351000     Rohtak            Sector 33
# 413    81771   189000  Faridabad  Parsvnath City Mall
#
# [414 rows x 9 columns]

# %%
new_order = ['Name Of Cars', 'Brand', 'Registration Year','Transmission','Fuel type','Kmt run','Price','Location_of_car','City Name']
df = df.reindex(columns=new_order)

# %%
df.rename(columns = {'Name Of Cars':'Name of Vehicle'},inplace =True)
df.rename(columns = {'Brand':'Brand of Vehicle'},inplace =True)
df.rename(columns = {'Location_of_car':'Location of Vehicle'},inplace =True)
df.rename(columns = {'City Name':'Name of City'},inplace =True)

# %%
df.rename(columns = {'Kmt run':'Kilometers Run'},inplace =True)

# %%
df
# Out:
#           Name of Vehicle Brand of Vehicle  Registration Year Transmission  \
# 0            Hyundai  i10          Hyundai               2010       Manual
# 1     Hyundai  Grand  i10          Hyundai               2016       Manual
# 2            Maruti  Ciaz           Maruti               2021       Manual
# 3               Honda  WR            Honda               2017       Manual
# 4          Maruti  Baleno           Maruti               2017    Automatic
# ..                    ...              ...                ...          ...
# 409   Hyundai  Grand  i10          Hyundai               2014    Automatic
# 410        Maruti  BREZZA           Maruti               2023       Manual
# 411       Maruti  Celerio           Maruti               2017       Manual
# 412   Hyundai  Grand  i10          Hyundai               2015       Manual
# 413         Maruti  Swift           Maruti               2011       Manual
#
#     Fuel type  Kilometers Run    Price  Location of Vehicle Name of City
# 0      Petrol           57942   247000              Attapur    Hyderabad
# 1      Petrol           75568   453000              Attapur    Hyderabad
# 2      Petrol           41362   819000             Kompally    Hyderabad
# 3      Diesel           53535   661000           Bachupally    Hyderabad
# 4      Petrol           41260   591000      Vanasthalipuram    Hyderabad
# ..        ...             ...      ...                  ...          ...
# 409    Petrol           26218   458000  Parsvnath City Mall    Faridabad
# 410    Petrol           11948  1190000  Parsvnath City Mall    Faridabad
# 411    Petrol          118486   325000  Parsvnath City Mall    Faridabad
# 412    Petrol           90358   351000            Sector 33       Rohtak
# 413    Petrol           81771   189000  Parsvnath City Mall    Faridabad
#
# [414 rows x 9 columns]

# %% [markdown]
# #### Saving file.csv

# %%
df.to_csv('WebScrapping&Data_Cleaning_Project.csv')
